# %%
# ==========================================================================
# SECTION 1: Setup and Imports
# ==========================================================================
import sys
import os
import time
import warnings
import numpy as np
from dataclasses import dataclass
from typing import Optional, Dict, Any, List, Tuple
from collections import defaultdict
import traceback

warnings.filterwarnings('ignore')

# Ensure src is in path
src_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
if src_path not in sys.path:
    sys.path.insert(0, src_path)

# Clear module cache for fresh import
import importlib
modules_to_clear = [k for k in list(sys.modules.keys()) if 'qectostim' in k]
for mod in modules_to_clear:
    del sys.modules[mod]
print(f"Cleared {len(modules_to_clear)} cached modules")

# Import testing utilities
from qectostim.testing import load_all_decoders, STATUS_OK, STATUS_WARN, STATUS_SKIP, STATUS_FAIL

# Import code discovery
from qectostim.codes import discover_all_codes

# Import noise models
from qectostim.noise.models import NoiseModel, CircuitDepolarizingNoise

# Import gadgets - Updated to include Bell-state teleportation
from qectostim.gadgets import (
    # Transversal gates
    TransversalHadamard, TransversalS, TransversalT,
    TransversalX, TransversalY, TransversalZ,
    TransversalCNOT, TransversalCZ, TransversalSWAP,
    # Teleportation-based gates (product-state - 2 block)
    TeleportedHadamard, TeleportedIdentity,
    # Bell-state teleportation (3 block) - NEW! Correctly implements S gate
    BellTeleportedS, BellTeleportedSDag,
    # CSS surgery
    LatticeZZMerge, LatticeXXMerge, SurgeryCNOT,
)

# Import experiment infrastructure
from qectostim.experiments.ft_gadget_experiment import FaultTolerantGadgetExperiment
from qectostim.gadgets.base import PhaseResult, PhaseType, ObservableTransform
from qectostim.gadgets.layout import QubitAllocation
from qectostim.experiments.stabilizer_rounds import DetectorContext
import stim

print("✓ All imports successful")
# Out:
# Cleared 0 cached modules
# ✓ All imports successful
# ✓ All imports successful

# %%
# ==========================================================================
# Load decoders and codes
# ==========================================================================
decoder_classes = load_all_decoders()
print(f"Loaded {len(decoder_classes)} decoders: {list(decoder_classes.keys())}")

all_codes = discover_all_codes(include_non_css=False)
print(f"Discovered {len(all_codes)} CSS codes")

# Standard noise model for testing
noise = CircuitDepolarizingNoise(p1=0.001, p2=0.001)
print(f"Noise model: CircuitDepolarizingNoise(p1=0.001, p2=0.001)")

# ==========================================================================
# Select ~10 representative test codes from discovered codes
# ==========================================================================
# Use discover_all_codes to get properly instantiated codes

# Find good test codes from the discovered set
target_codes = [
    'FourQubit422Code',     # Small CSS [[4,2,2]]
    'SixQubit622Code',      # Small CSS [[6,2,2]]
    'SteanCode713',         # Classic [[7,1,3]]
    'ShorCode91',           # Shor's [[9,1,3]]
    'HammingCSSCode_m3',    # Hamming-based
    'RotatedSurfaceCode_d3',# Rotated surface
    'ToricCode33',          # Toric code
    'XZZXSurfaceCode_d3',   # XZZX variant
    'TriangularColourCode_d3', # Color code
    'RepetitionCode_d5',    # Repetition
    'XZZX_Surface_3',
    'LoopToricCode4D',
    'Hamming_CSS_15',
    'Code_832',
    'Colour488_[[9,1,3]]',
    'QuantumTanner_4',
    'BalancedProduct_5x5_G1'


]

# Build TEST_CODES from discovered codes, falling back to known-good codes
TEST_CODES = {}

# First try discovered codes
for name in target_codes:
    if name in all_codes:
        TEST_CODES[name] = all_codes[name]

# Add fallback small codes if we didn't find 10
from qectostim.codes.small.four_two_two import FourQubit422Code
from qectostim.codes.small.steane_713 import SteanCode713
from qectostim.codes.small.shor_code import ShorCode91

# Always include the basic test codes
TEST_CODES['FourQubit422'] = FourQubit422Code()
TEST_CODES['SteanCode713'] = SteanCode713()
TEST_CODES['ShorCode91'] = ShorCode91()

# Try to add more from discovered codes matching patterns
for name, code in all_codes.items():
    # if len(TEST_CODES) >= 10:
    #     break
    # Add interesting codes
    if any(x in name for x in ['Surface', 'Toric', 'Color', 'Colour', 'XZZX']):
        if name not in TEST_CODES:
            TEST_CODES[name] = code

print(f"\nTest codes ({len(TEST_CODES)} total):")
for name, code in TEST_CODES.items():
    n = code.n
    k = code.k if hasattr(code, 'k') else '?'
    d = code.d if hasattr(code, 'd') else '?'
    print(f"  {name:<30}: [[{n}, {k}, {d}]]")
# Out:
# Loaded 13 decoders: ['PyMatching', 'FusionBlossom', 'BeliefMatching', 'BPOSD', 'Tesseract', 'UnionFind', 'MLE', 'Hypergraph', 'Chromobius', 'Concatenated', 'FlatConcat', 'Hierarchical', 'SingleShot']
# Discovered 76 CSS codes
# Noise model: CircuitDepolarizingNoise(p1=0.001, p2=0.001)
#
# Test codes (36 total):
#   XZZX_Surface_3                : [[9, 1, ?]]
#   LoopToricCode4D               : [[8, 2, ?]]
#   Hamming_CSS_15                : [[15, 7, ?]]
#   Code_832                      : [[8, 3, ?]]
#   Colour488_[[9,1,3]]           : [[9, 1, ?]]
#   QuantumTanner_4               : [[32, 2, ?]]
#   BalancedProduct_5x5_G1        : [[41, 1, ?]]
#   FourQubit422                  : [[4, 2, ?]]
#   SteanCode713                  : [[7, 1, ?]]
#   ShorCode91                    : [[9, 1, ?]]
#   RotatedSurface_[[9,1,3]]      : [[9, 1, ?]]
#   RotatedSurface_[[25,1,5]]     : [[25, 1, ?]]
#   ToricCode_3x3                 : [[18, 2, ?]]
#   ToricCode_5x5                 : [[50, 2, ?]]
#   XZZX_Surface_5                : [[25, 1, ?]]
#   ToricCode4D_2                 : [[96, 6, ?]]
#   ToricCode4D_3                 : [[486, 6, ?]]
#   ToricCode3D_3x3x3             : [[81, 3, ?]]
# Discovered 76 CSS codes
# Noise model: CircuitDepolarizingNoise(p1=0.001, p2=0.001)
#
# Test codes (36 total):
#   XZZX_Surface_3                : [[9, 1, ?]]
#   LoopToricCode4D               : [[8, 2, ?]]
#   Hamming_CSS_15                : [[15, 7, ?]]
#   Code_832                      : [[8, 3, ?]]
#   Colour488_[[9,1,3]]           : [[9, 1, ?]]
#   QuantumTanner_4               : [[32, 2, ?]]
#   BalancedProduct_5x5_G1        : [[41, 1, ?]]
#   FourQubit422                  : [[4, 2, ?]]
#   SteanCode713                  : [[7, 1, ?]]
#   ShorCode91                    : [[9, 1, ?]]
#   RotatedSurface_[[9,1,3]]      : [[9, 1, ?]]
#   RotatedSurface_[[25,1,5]]     : [[25, 1, ?]]
#   ToricCode_3x3                 : [[18, 2, ?]]
#   ToricCode_5x5                 : [[50, 2, ?]]
#   XZZX_Surface_5                : [[25, 1, ?]]
#   ToricCode4D_2                 : [[96, 6, ?]]
#   ToricCode4D_3                 : [[486, 6, ?]]
#   ToricCode3D_3x3x3             : [[81, 3, ?]]
#   ToricCode3D_4x4x4             : [[192, 3, ?]]
#   ToricCode3DFaces_3x3x3        : [[81, 3, ?]]
#   HyperbolicSurfaceCode         : [[25, 1, ?]]
#   TwistedToric_[[32,2,None]]    : [[32, 2, ?]]
#   TwistedToric_4x4_[[32,2,None]]: [[32, 2, ?]]
#   ProjectivePlaneSurface_[[13,1,None]]: [[13, 1, ?]]
#   TriangularColour_d3           : [[7, 1, ?]]
#   TriangularColour_d5           : [[19, 1, ?]]
#   HexagonalColour_d2            : [[8, 2, ?]]
#   HexagonalColour_d3            : [[17, 7, ?]]
#   TruncatedTrihexColorCode      : [[61, 1, ?]]
#   ColorCode3D_d3                : [[15, 7, ?]]
#   ColorCode3D_d5                : [[102, 27, ?]]
#   ColorCode3DPrism_2x3          : [[24, 5, ?]]
#   TetrahedralColorCode          : [[7, 1, ?]]
#   BallColorCode                 : [[15, 7, ?]]
#   HyperbolicColorCode           : [[32, 2, ?]]
#   GaugeColor_3                  : [[22, 18, ?]]
#   ToricCode3D_4x4x4             : [[192, 3, ?]]
#   ToricCode3DFaces_3x3x3        : [[81, 3, ?]]
#   HyperbolicSurfaceCode         : [[25, 1, ?]]
#   TwistedToric_[[32,2,None]]    : [[32, 2, ?]]
#   TwistedToric_4x4_[[32,2,None]]: [[32, 2, ?]]
#   ProjectivePlaneSurface_[[13,1,None]]: [[13, 1, ?]]
#   TriangularColour_d3           : [[7, 1, ?]]
#   TriangularColour_d5           : [[19, 1, ?]]
#   HexagonalColour_d2            : [[8, 2, ?]]
#   HexagonalColour_d3            : [[17, 7, ?]]
#   TruncatedTrihexColorCode      : [[61, 1, ?]]
#   ColorCode3D_d3                : [[15, 7, ?]]
#   ColorCode3D_d5                : [[102, 27, ?]]
#   ColorCode3DPrism_2x3          : [[24, 5, ?]]
#   TetrahedralColorCode          : [[7, 1, ?]]
#   BallColorCode                 : [[15, 7, ?]]
#   HyperbolicColorCode           : [[32, 2, ?]]
#   GaugeColor_3                  : [[22, 18, ?]]

# %% [markdown]
# ## Section 2: Zero-Noise Verification
#
# **Critical Sanity Check**: With no noise, the logical error rate MUST be 0.
#
# If LER ≠ 0 with no noise, it indicates:
# - Observable tracking bug (wrong qubits in OBSERVABLE_INCLUDE)
# - Detector emission bug (wrong measurements referenced)
# - Gate implementation bug (wrong physical operations)

# %%
# ==========================================================================
# SECTION 2: Zero-Noise Verification Helper
# ==========================================================================

# Known non-working gadgets (expected to fail)
KNOWN_BROKEN_GADGETS = {
    'TransversalT': 'Non-Clifford (Stim cannot simulate)',
}

def verify_zero_noise(
    gadget,
    codes: List,
    gadget_name: str,
    num_shots: int = 1000,
    measurement_basis: str = "Z",
) -> Tuple[bool, float, Optional[str]]:
    """
    Verify that a gadget produces LER=0 with no noise.
    
    Returns (passed, ler, error_message)
    """
    try:
        exp = FaultTolerantGadgetExperiment(
            codes=codes,
            gadget=gadget,
            noise_model=None,  # NO NOISE!
            num_rounds_before=1,
            num_rounds_after=1,
            measurement_basis=measurement_basis,
        )
        
        passed, ler, error_msg = exp.verify_zero_noise_ler(num_shots)
        return passed, ler, error_msg
        
    except Exception as e:
        return False, 1.0, f"Exception: {e}"


def run_zero_noise_tests(gadgets_config: Dict, test_code, test_code_name: str):
    """
    Run zero-noise verification on all gadgets.
    """
    print("=" * 80)
    print(f"ZERO-NOISE VERIFICATION on {test_code_name}")
    print("=" * 80)
    print("Gadget                        | Status | LER    | Notes")
    print("-" * 80)
    
    results = {}
    for name, (cls, kwargs, is_two_qubit) in gadgets_config.items():
        # Check if this is a known broken gadget
        if name in KNOWN_BROKEN_GADGETS:
            reason = KNOWN_BROKEN_GADGETS[name]
            print(f"{name:<30} | ~ SKIP | --     | {reason[:35]}")
            results[name] = {'passed': None, 'ler': None, 'error': reason, 'skipped': True}
            continue
        
        try:
            gadget = cls(**kwargs)
            codes = [test_code, test_code] if is_two_qubit else [test_code]
            
            passed, ler, error_msg = verify_zero_noise(gadget, codes, name, measurement_basis="Z")
            
            status = "✓ PASS" if passed else "✗ FAIL"
            notes = error_msg if error_msg else ""
            print(f"{name:<30} | {status:<6} | {ler:.4f} | {notes[:35]}")
            results[name] = {'passed': passed, 'ler': ler, 'error': error_msg}
            
        except Exception as e:
            print(f"{name:<30} | ✗ ERR  | --     | {str(e)[:35]}")
            results[name] = {'passed': False, 'ler': None, 'error': str(e)}
    
    print("-" * 80)
    passed_count = sum(1 for r in results.values() if r.get('passed', False))
    skipped_count = sum(1 for r in results.values() if r.get('skipped', False))
    tested_count = len(results) - skipped_count
    print(f"\nSummary: {passed_count}/{tested_count} passed zero-noise verification")
    print(f"         {skipped_count} skipped (known broken)")
    
    return results

# %%
# ==========================================================================
# Define all gadgets for testing
# ==========================================================================

SINGLE_QUBIT_GADGETS = {
    'TransversalH': (TransversalHadamard, {'include_stabilizer_rounds': False}, False),
    'TransversalS': (TransversalS, {'include_stabilizer_rounds': False}, False),
    'TransversalT': (TransversalT, {'include_stabilizer_rounds': False}, False),  # Non-Clifford - expected to fail
    'TransversalX': (TransversalX, {'include_stabilizer_rounds': False}, False),
    'TransversalY': (TransversalY, {'include_stabilizer_rounds': False}, False),
    'TransversalZ': (TransversalZ, {'include_stabilizer_rounds': False}, False),
}

TWO_QUBIT_GADGETS = {
    'TransversalCNOT': (TransversalCNOT, {'include_stabilizer_rounds': False}, True),
    'TransversalCZ': (TransversalCZ, {'include_stabilizer_rounds': False}, True),
    'TransversalSWAP': (TransversalSWAP, {'include_stabilizer_rounds': False}, True),
}

# Teleportation gadgets:
# - Product-state (2 blocks): TeleportedH, TeleportedIdentity
# - Bell-state (3 blocks): BellTeleportedS, BellTeleportedSDag (NEW - fixes S gate issue!)
TELEPORTATION_GADGETS = {
    # Product-state teleportation (2 blocks) - works for H and Identity
    'TeleportedH': (TeleportedHadamard, {'include_stabilizer_rounds': False}, False),
    'TeleportedIdentity': (TeleportedIdentity, {'include_stabilizer_rounds': False}, False),
    # Bell-state teleportation (3 blocks) - CORRECTLY implements S gate!
    'BellTeleportedS': (BellTeleportedS, {}, False),
    'BellTeleportedSDag': (BellTeleportedSDag, {}, False),
}

# Note: Legacy TeleportedS and TeleportedT are BROKEN and excluded
# - TeleportedS: Product-state ancilla |+i⟩ doesn't give correct S transformation
# - TeleportedT: Same issue PLUS Stim cannot simulate non-Clifford T gate

SURGERY_GADGETS = {
    'LatticeZZMerge': (LatticeZZMerge, {'num_merge_rounds': 1}, True),
    'LatticeXXMerge': (LatticeXXMerge, {'num_merge_rounds': 1}, True),
    'SurgeryCNOT': (SurgeryCNOT, {'num_rounds_before': 0, 'num_rounds_after': 0, 'num_merge_rounds': 1}, True),
}

ALL_GADGETS = {
    **SINGLE_QUBIT_GADGETS,
    **TWO_QUBIT_GADGETS,
    **TELEPORTATION_GADGETS,
    **SURGERY_GADGETS,
}

print(f"Defined {len(ALL_GADGETS)} gadgets for testing:")
print(f"  Single-qubit transversal: {list(SINGLE_QUBIT_GADGETS.keys())}")
print(f"  Two-qubit transversal: {list(TWO_QUBIT_GADGETS.keys())}")
print(f"  Teleportation (product+Bell): {list(TELEPORTATION_GADGETS.keys())}")
print(f"  Surgery: {list(SURGERY_GADGETS.keys())}")
print(f"\nNote: TransversalT is included but expected to fail (non-Clifford)")
# Out:
# Defined 16 gadgets for testing:
#   Single-qubit transversal: ['TransversalH', 'TransversalS', 'TransversalT', 'TransversalX', 'TransversalY', 'TransversalZ']
#   Two-qubit transversal: ['TransversalCNOT', 'TransversalCZ', 'TransversalSWAP']
#   Teleportation (product+Bell): ['TeleportedH', 'TeleportedIdentity', 'BellTeleportedS', 'BellTeleportedSDag']
#   Surgery: ['LatticeZZMerge', 'LatticeXXMerge', 'SurgeryCNOT']
#
# Note: TransversalT is included but expected to fail (non-Clifford)

# %%
# ==========================================================================
# Decoder Compatibility Test Infrastructure
# ==========================================================================

STATUS_OK = 'OK'
STATUS_WARN = 'WARN'
STATUS_FAIL = 'FAIL'
STATUS_SKIP = 'SKIP'
STATUS_NA = 'N/A'

# Decoders that have special requirements
SPECIALIZED_DECODERS = {
    'Chromobius': 'color_code',  # Requires color code with 4th coordinate annotations
    'Concatenated': 'concatenated_code',  # Requires ConcatenatedCode
    'FlatConcat': 'concatenated_code',  # Requires ConcatenatedCode
    'MLE': 'small_detector_count',  # MLE is only practical for ≤30 detectors
}

MLE_MAX_DETECTORS = 30  # MLEDecoder limit

def check_decoder_compatibility(decoder_name: str, code, code_name: str, circuit=None) -> Tuple[bool, str]:
    """Check if a decoder is compatible with a code.
    
    Returns (is_compatible, reason) tuple.
    
    Parameters
    ----------
    decoder_name : str
        Name of the decoder
    code : Code
        The code being tested
    code_name : str
        Name of the code
    circuit : stim.Circuit, optional
        The Stim circuit (needed for detector count checks)
    """
    requirement = SPECIALIZED_DECODERS.get(decoder_name)
    
    if requirement == 'color_code':
        # Chromobius requires color codes with proper annotations
        meta = getattr(code, 'metadata', {}) if hasattr(code, 'metadata') else {}
        if not meta.get('is_chromobius_compatible', False):
            return False, "Requires color code"
    
    elif requirement == 'concatenated_code':
        # Concatenated decoders require ConcatenatedCode
        code_class_name = type(code).__name__
        if 'Concatenated' not in code_class_name:
            return False, "Requires concatenated code"
    
    elif requirement == 'small_detector_count':
        # MLE decoder is only practical for small detector counts
        if circuit is not None and circuit.num_detectors > MLE_MAX_DETECTORS:
            return False, f">30 detectors ({circuit.num_detectors})"
    
    return True, ""

def test_gadget_decoder(
    code,
    code_name: str,
    gadget_class,
    gadget_kwargs: Dict,
    decoder_class,
    decoder_name: str,
    is_two_qubit: bool = False,
    shots: int = 1000,
) -> Dict[str, Any]:
    """
    Test a gadget+decoder combination on a code.
    """
    result = {
        'status': STATUS_FAIL,
        'ler': None,
        'error': None,
    }
    
    # Check decoder compatibility BEFORE running experiment (code-level checks)
    is_compatible, reason = check_decoder_compatibility(decoder_name, code, code_name)
    if not is_compatible:
        result['status'] = STATUS_SKIP
        result['error'] = reason
        return result
    
    try:
        gadget = gadget_class(**gadget_kwargs)
        codes = [code, code] if is_two_qubit else [code]
        
        noise = CircuitDepolarizingNoise(p1=0.001, p2=0.001)
        exp = FaultTolerantGadgetExperiment(
            codes=codes,
            gadget=gadget,
            noise_model=noise,
            num_rounds_before=2,
            num_rounds_after=2,
        )
        
        circuit = exp.to_stim()
        
        if circuit.num_detectors == 0:
            result['status'] = STATUS_SKIP
            result['error'] = 'No detectors'
            return result
        
        # Check decoder compatibility AFTER circuit generation (circuit-level checks like detector count)
        is_compatible, reason = check_decoder_compatibility(decoder_name, code, code_name, circuit=circuit)
        if not is_compatible:
            result['status'] = STATUS_SKIP
            result['error'] = reason
            return result
        
        # Try to decode
        try:
            dem = circuit.detector_error_model(decompose_errors=True)
            
            # Create decoder - use dataclass pattern (dem=dem), not classmethod
            decoder = decoder_class(dem=dem)
            
            sampler = circuit.compile_detector_sampler()
            samples = sampler.sample(shots, append_observables=True)
            
            det_samples = samples[:, :circuit.num_detectors]
            obs_samples = samples[:, circuit.num_detectors:]
            
            predictions = decoder.decode_batch(det_samples)
            if len(predictions.shape) == 1:
                predictions = predictions.reshape(-1, 1)
            
            errors = np.any(predictions != obs_samples, axis=1)
            result['ler'] = float(np.mean(errors))
            result['status'] = STATUS_OK
            
        except Exception as e:
            result['status'] = STATUS_WARN
            result['error'] = str(e)[:50]
    
    except Exception as e:
        result['status'] = STATUS_FAIL
        result['error'] = str(e)[:50]
    
    return result


def run_decoder_matrix(
    gadgets_config: Dict,
    test_codes: Dict,
    decoder_classes: Dict,
    category_name: str,
) -> Dict:
    """
    Run decoder compatibility matrix for a gadget category.
    """
    
    all_results = {}
    rows = []
    dec_names = list(decoder_classes.keys())
    
    for gadget_name, (gadget_class, gadget_kwargs, is_two_qubit) in gadgets_config.items():
        all_results[gadget_name] = {}
        for code_name, code in test_codes.items():
            all_results[gadget_name][code_name] = {}
            
            row = f"{gadget_name:<20} | {code_name:<20}"
            
            for dec_name in dec_names:
                result = test_gadget_decoder(
                    code=code,
                    code_name=code_name,
                    gadget_class=gadget_class,
                    gadget_kwargs=gadget_kwargs,
                    decoder_class=decoder_classes[dec_name],
                    decoder_name=dec_name,
                    is_two_qubit=is_two_qubit,
                )
                
                all_results[gadget_name][code_name][dec_name] = result
                
                if result['status'] == STATUS_OK:
                    cell = f"{result['ler']:.3f}" if result['ler'] is not None else "  OK  "
                elif result['status'] == STATUS_SKIP:
                    cell = " SKIP "
                elif result['status'] == STATUS_WARN:
                    cell = " WARN "
                else:
                    cell = " FAIL "
                
                row += f" | {cell:^8}"
            rows.append(row)

    print("=" * 140)
    print(f"DECODER COMPATIBILITY: {category_name}")
    print("=" * 140)

    
    header = f"{'Gadget':<20} | {'Code':<20}"
    for dec in dec_names:
        header += f" | {dec[:8]:^8}"
    print(header)
    print("-" * len(header))
    for r in rows:
        print(r)
    
    print("-" * len(header))
    return all_results

# %%
# ==========================================================================
# COMPREHENSIVE TEST: All Gadgets x All Codes
# ==========================================================================
from qectostim.decoders import PyMatchingDecoder
print("=" * 100)
print("COMPREHENSIVE GADGET TEST: All Gadgets x All Codes")
print("=" * 100)

# Build results matrix
all_results = {}
code_names = list(TEST_CODES.keys())

# Header
header = f"{'Gadget':<20}"
for code_name in code_names:
    header += f" | {code_name[:12]:<12}"
print(header)
print("-" * len(header))

for gadget_name, (cls, kwargs, is_two) in ALL_GADGETS.items():
    row = f"{gadget_name:<20}"
    all_results[gadget_name] = {}
    
    for code_name, code in TEST_CODES.items():
        try:
            gadget = cls(**kwargs)
            codes = [code, code] if is_two else [code]
            
            exp = FaultTolerantGadgetExperiment(
                codes=codes,
                gadget=gadget,
                noise_model=noise,
                num_rounds_before=2,
                num_rounds_after=2,
            )
            
            circuit = exp.to_stim()
            
            if circuit.num_detectors == 0:
                all_results[gadget_name][code_name] = ('SKIP', 'No dets')
                row += f" | {'SKIP':^12}"
                continue
            
            dem = circuit.detector_error_model(decompose_errors=True)
            decoder = PyMatchingDecoder(dem=dem)
            
            sampler = circuit.compile_detector_sampler()
            samples = sampler.sample(2000, append_observables=True)
            
            det_samples = samples[:, :circuit.num_detectors]
            obs_samples = samples[:, circuit.num_detectors:]
            
            predictions = decoder.decode_batch(det_samples)
            if len(predictions.shape) == 1:
                predictions = predictions.reshape(-1, 1)
            
            errors = np.any(predictions != obs_samples, axis=1)
            ler = float(np.mean(errors))
            
            all_results[gadget_name][code_name] = ('OK', ler)
            row += f" | {ler:^12.4f}"
            
        except Exception as e:
            err_msg = str(e).lower()
            if "non-deterministic" in err_msg:
                all_results[gadget_name][code_name] = ('DET', str(e)[:30])
                row += f" | {'DET_ERR':^12}"
            elif "non-clifford" in err_msg or "notimplementederror" in err_msg:
                all_results[gadget_name][code_name] = ('SKIP', 'NonCliff')
                row += f" | {'SKIP':^12}"
            else:
                all_results[gadget_name][code_name] = ('FAIL', str(e)[:30])
                row += f" | {'FAIL':^12}"
    
    print(row)

print("-" * len(header))

# Summary statistics
print("\n" + "=" * 100)
print("RESULTS SUMMARY")
print("=" * 100)

status_counts = {'OK': 0, 'DET': 0, 'SKIP': 0, 'FAIL': 0}
problem_cases = []

for gadget_name, code_results in all_results.items():
    for code_name, (status, info) in code_results.items():
        if status == 'OK':
            status_counts['OK'] += 1
        elif status == 'DET':
            status_counts['DET'] += 1
            problem_cases.append((gadget_name, code_name, 'Non-deterministic detectors'))
        elif status == 'SKIP':
            status_counts['SKIP'] += 1
        else:
            status_counts['FAIL'] += 1
            problem_cases.append((gadget_name, code_name, info))

total = sum(status_counts.values())
print(f"\nTotal test cases: {total}")
print(f"  ✓ OK:      {status_counts['OK']} ({100*status_counts['OK']/total:.1f}%)")
print(f"  ⚠ DET_ERR: {status_counts['DET']} ({100*status_counts['DET']/total:.1f}%)")
print(f"  ~ SKIP:    {status_counts['SKIP']} ({100*status_counts['SKIP']/total:.1f}%)")
print(f"  ✗ FAIL:    {status_counts['FAIL']} ({100*status_counts['FAIL']/total:.1f}%)")

if problem_cases:
    print("\n" + "=" * 100)
    print("PROBLEM CASES REQUIRING INVESTIGATION")
    print("=" * 100)
    for gadget, code, msg in problem_cases:
        print(f"  {gadget:<20} + {code:<20}: {msg[:40]}")
# Out:
# ====================================================================================================
# COMPREHENSIVE GADGET TEST: All Gadgets x All Codes
# ====================================================================================================
# Gadget               | XZZX_Surface | LoopToricCod | Hamming_CSS_ | Code_832     | Colour488_[[ | QuantumTanne | BalancedProd | FourQubit422 | SteanCode713 | ShorCode91   | RotatedSurfa | RotatedSurfa | ToricCode_3x | ToricCode_5x | XZZX_Surface | ToricCode4D_ | ToricCode4D_ | ToricCode3D_ | ToricCode3D_ | ToricCode3DF | HyperbolicSu | TwistedToric | TwistedToric | ProjectivePl | TriangularCo | TriangularCo | HexagonalCol | HexagonalCol | TruncatedTri | ColorCode3D_ | ColorCode3D_ | ColorCode3DP | TetrahedralC | BallColorCod | HyperbolicCo | GaugeColor_3
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# TransversalH         |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |   DET_ERR
# TransversalH         |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |   DET_ERR
# TransversalS         |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |   DET_ERR
# TransversalS         |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |   DET_ERR
# TransversalT         |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     FAIL     |     FAIL     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP
# TransversalT         |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     FAIL     |     FAIL     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP     |     SKIP
# TransversalX         |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |   DET_ERR
# TransversalX         |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |   DET_ERR
# TransversalY         |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |   DET_ERR
# TransversalY         |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |   DET_ERR
# TransversalZ         |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |   DET_ERR
# TransversalZ         |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |   DET_ERR
# TransversalCNOT      |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |   DET_ERR
# TransversalCNOT      |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |   DET_ERR
# TransversalCZ        |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |   DET_ERR
# TransversalCZ        |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |   DET_ERR
# TransversalSWAP      |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |   DET_ERR
# TransversalSWAP      |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |   DET_ERR
# TeleportedH          |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |   DET_ERR
# TeleportedH          |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |   DET_ERR
# TeleportedIdentity   |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |   DET_ERR
# TeleportedIdentity   |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |   DET_ERR
# BellTeleportedS      |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |   DET_ERR
# BellTeleportedS      |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |   DET_ERR
# BellTeleportedSDag   |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |   DET_ERR
# BellTeleportedSDag   |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |   DET_ERR
# LatticeZZMerge       |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |   DET_ERR
# LatticeZZMerge       |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |   DET_ERR
# LatticeXXMerge       |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |   DET_ERR
# LatticeXXMerge       |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |   DET_ERR
# SurgeryCNOT          |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |     FAIL     |   DET_ERR    |     FAIL     |   DET_ERR    |   DET_ERR    |   DET_ERR    |   DET_ERR    |     FAIL     |     FAIL     |   DET_ERR
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# ====================================================================================================
# RESULTS SUMMARY
# ====================================================================================================
#
# Total test cases: 576
#   ✓ OK:      0 (0.0%)
#   ⚠ DET_ERR: 150 (26.0%)
#   ~ SKIP:    34 (5.9%)
#   ✗ FAIL:    392 (68.1%)
#
# ====================================================================================================
# PROBLEM CASES REQUIRING INVESTIGATION
# ====================================================================================================
#   TransversalH         + XZZX_Surface_3      : name 'PyMatchingDecoder' is no
#   TransversalH         + LoopToricCode4D     : Failed to decompose errors int
#   TransversalH         + Hamming_CSS_15      : name 'PyMatchingDecoder' is no
#   TransversalH         + Code_832            : name 'PyMatchingDecoder' is no
#   TransversalH         + Colour488_[[9,1,3]] : name 'PyMatchingDecoder' is no
#   TransversalH         + QuantumTanner_4     : Code 'QuantumTannerCode' is no
#   TransversalH         + BalancedProduct_5x5_G1: Code 'BalancedProductCode' is
#   TransversalH         + FourQubit422        : name 'PyMatchingDecoder' is no
#   TransversalH         + SteanCode713        : name 'PyMatchingDecoder' is no
#   TransversalH         + ShorCode91          : name 'PyMatchingDecoder' is no
#   TransversalH         + RotatedSurface_[[9,1,3]]: name 'PyMatchingDecoder' is no
#   TransversalH         + RotatedSurface_[[25,1,5]]: Failed to decompose errors int
#   TransversalH         + ToricCode_3x3       : Failed to decompose errors int
#   TransversalH         + ToricCode_5x5       : Non-deterministic detectors
#   TransversalH         + XZZX_Surface_5      : name 'PyMatchingDecoder' is no
#   TransversalH         + ToricCode4D_2       : An error case in a composite e
#   TransversalH         + ToricCode4D_3       : An error case in a composite e
#   TransversalH         + ToricCode3D_3x3x3   : Non-deterministic detectors
#   TransversalH         + ToricCode3D_4x4x4   : Non-deterministic detectors
#   TransversalH         + ToricCode3DFaces_3x3x3: Non-deterministic detectors
#   TransversalH         + HyperbolicSurfaceCode: name 'PyMatchingDecoder' is no
#   TransversalH         + TwistedToric_[[32,2,None]]: Failed to decompose errors int
#   TransversalH         + TwistedToric_4x4_[[32,2,None]]: Failed to decompose errors int
#   TransversalH         + ProjectivePlaneSurface_[[13,1,None]]: name 'PyMatchingDecoder' is no
#   TransversalH         + TriangularColour_d3 : name 'PyMatchingDecoder' is no
#   TransversalH         + TriangularColour_d5 : Failed to decompose errors int
#   TransversalH         + HexagonalColour_d2  : name 'PyMatchingDecoder' is no
#   TransversalH         + HexagonalColour_d3  : Non-deterministic detectors
#   TransversalH         + TruncatedTrihexColorCode: Failed to decompose errors int
#   TransversalH         + ColorCode3D_d3      : Non-deterministic detectors
#   TransversalH         + ColorCode3D_d5      : Non-deterministic detectors
#   TransversalH         + ColorCode3DPrism_2x3: Non-deterministic detectors
#   TransversalH         + TetrahedralColorCode: Non-deterministic detectors
#   TransversalH         + BallColorCode       : name 'PyMatchingDecoder' is no
#   TransversalH         + HyperbolicColorCode : Failed to decompose errors int
#   TransversalH         + GaugeColor_3        : Non-deterministic detectors
#   TransversalS         + XZZX_Surface_3      : name 'PyMatchingDecoder' is no
#   TransversalS         + LoopToricCode4D     : Failed to decompose errors int
#   TransversalS         + Hamming_CSS_15      : name 'PyMatchingDecoder' is no
#   TransversalS         + Code_832            : Failed to decompose errors int
#   TransversalS         + Colour488_[[9,1,3]] : name 'PyMatchingDecoder' is no
#   TransversalS         + QuantumTanner_4     : Code 'QuantumTannerCode' is no
#   TransversalS         + BalancedProduct_5x5_G1: Code 'BalancedProductCode' is
#   TransversalS         + FourQubit422        : name 'PyMatchingDecoder' is no
#   TransversalS         + SteanCode713        : name 'PyMatchingDecoder' is no
#   TransversalS         + ShorCode91          : name 'PyMatchingDecoder' is no
#   TransversalS         + RotatedSurface_[[9,1,3]]: name 'PyMatchingDecoder' is no
#   TransversalS         + RotatedSurface_[[25,1,5]]: Failed to decompose errors int
#   TransversalS         + ToricCode_3x3       : Failed to decompose errors int
#   TransversalS         + ToricCode_5x5       : Non-deterministic detectors
#   TransversalS         + XZZX_Surface_5      : name 'PyMatchingDecoder' is no
#   TransversalS         + ToricCode4D_2       : An error case in a composite e
#   TransversalS         + ToricCode4D_3       : An error case in a composite e
#   TransversalS         + ToricCode3D_3x3x3   : Non-deterministic detectors
#   TransversalS         + ToricCode3D_4x4x4   : Non-deterministic detectors
#   TransversalS         + ToricCode3DFaces_3x3x3: Non-deterministic detectors
#   TransversalS         + HyperbolicSurfaceCode: name 'PyMatchingDecoder' is no
#   TransversalS         + TwistedToric_[[32,2,None]]: Failed to decompose errors int
#   TransversalS         + TwistedToric_4x4_[[32,2,None]]: Failed to decompose errors int
#   TransversalS         + ProjectivePlaneSurface_[[13,1,None]]: name 'PyMatchingDecoder' is no
#   TransversalS         + TriangularColour_d3 : name 'PyMatchingDecoder' is no
#   TransversalS         + TriangularColour_d5 : Failed to decompose errors int
#   TransversalS         + HexagonalColour_d2  : name 'PyMatchingDecoder' is no
#   TransversalS         + HexagonalColour_d3  : Non-deterministic detectors
#   TransversalS         + TruncatedTrihexColorCode: Failed to decompose errors int
#   TransversalS         + ColorCode3D_d3      : Non-deterministic detectors
#   TransversalS         + ColorCode3D_d5      : Non-deterministic detectors
#   TransversalS         + ColorCode3DPrism_2x3: Non-deterministic detectors
#   TransversalS         + TetrahedralColorCode: Non-deterministic detectors
#   TransversalS         + BallColorCode       : name 'PyMatchingDecoder' is no
#   TransversalS         + HyperbolicColorCode : Failed to decompose errors int
#   TransversalS         + GaugeColor_3        : Non-deterministic detectors
#   TransversalT         + QuantumTanner_4     : Code 'QuantumTannerCode' is no
#   TransversalT         + BalancedProduct_5x5_G1: Code 'BalancedProductCode' is
#   TransversalX         + XZZX_Surface_3      : name 'PyMatchingDecoder' is no
#   TransversalX         + LoopToricCode4D     : name 'PyMatchingDecoder' is no
#   TransversalX         + Hamming_CSS_15      : name 'PyMatchingDecoder' is no
#   TransversalX         + Code_832            : Failed to decompose errors int
#   TransversalX         + Colour488_[[9,1,3]] : name 'PyMatchingDecoder' is no
#   TransversalX         + QuantumTanner_4     : Code 'QuantumTannerCode' is no
#   TransversalX         + BalancedProduct_5x5_G1: Code 'BalancedProductCode' is
#   TransversalX         + FourQubit422        : name 'PyMatchingDecoder' is no
#   TransversalX         + SteanCode713        : name 'PyMatchingDecoder' is no
#   TransversalX         + ShorCode91          : name 'PyMatchingDecoder' is no
#   TransversalX         + RotatedSurface_[[9,1,3]]: name 'PyMatchingDecoder' is no
#   TransversalX         + RotatedSurface_[[25,1,5]]: name 'PyMatchingDecoder' is no
#   TransversalX         + ToricCode_3x3       : name 'PyMatchingDecoder' is no
#   TransversalX         + ToricCode_5x5       : Non-deterministic detectors
#   TransversalX         + XZZX_Surface_5      : name 'PyMatchingDecoder' is no
#   TransversalX         + ToricCode4D_2       : Failed to decompose errors int
#   TransversalX         + ToricCode4D_3       : Failed to decompose errors int
#   TransversalX         + ToricCode3D_3x3x3   : Non-deterministic detectors
#   TransversalX         + ToricCode3D_4x4x4   : Non-deterministic detectors
#   TransversalX         + ToricCode3DFaces_3x3x3: Non-deterministic detectors
#   TransversalX         + HyperbolicSurfaceCode: name 'PyMatchingDecoder' is no
#   TransversalX         + TwistedToric_[[32,2,None]]: name 'PyMatchingDecoder' is no
#   TransversalX         + TwistedToric_4x4_[[32,2,None]]: name 'PyMatchingDecoder' is no
#   TransversalX         + ProjectivePlaneSurface_[[13,1,None]]: name 'PyMatchingDecoder' is no
#   TransversalX         + TriangularColour_d3 : name 'PyMatchingDecoder' is no
#   TransversalX         + TriangularColour_d5 : Failed to decompose errors int
#   TransversalX         + HexagonalColour_d2  : name 'PyMatchingDecoder' is no
#   TransversalX         + HexagonalColour_d3  : Non-deterministic detectors
#   TransversalX         + TruncatedTrihexColorCode: name 'PyMatchingDecoder' is no
#   TransversalX         + ColorCode3D_d3      : Non-deterministic detectors
#   TransversalX         + ColorCode3D_d5      : Non-deterministic detectors
#   TransversalX         + ColorCode3DPrism_2x3: Non-deterministic detectors
#   TransversalX         + TetrahedralColorCode: Non-deterministic detectors
#   TransversalX         + BallColorCode       : name 'PyMatchingDecoder' is no
#   TransversalX         + HyperbolicColorCode : name 'PyMatchingDecoder' is no
#   TransversalX         + GaugeColor_3        : Non-deterministic detectors
#   TransversalY         + XZZX_Surface_3      : name 'PyMatchingDecoder' is no
#   TransversalY         + LoopToricCode4D     : name 'PyMatchingDecoder' is no
#   TransversalY         + Hamming_CSS_15      : name 'PyMatchingDecoder' is no
#   TransversalY         + Code_832            : Failed to decompose errors int
#   TransversalY         + Colour488_[[9,1,3]] : name 'PyMatchingDecoder' is no
#   TransversalY         + QuantumTanner_4     : Code 'QuantumTannerCode' is no
#   TransversalY         + BalancedProduct_5x5_G1: Code 'BalancedProductCode' is
#   TransversalY         + FourQubit422        : name 'PyMatchingDecoder' is no
#   TransversalY         + SteanCode713        : name 'PyMatchingDecoder' is no
#   TransversalY         + ShorCode91          : name 'PyMatchingDecoder' is no
#   TransversalY         + RotatedSurface_[[9,1,3]]: name 'PyMatchingDecoder' is no
#   TransversalY         + RotatedSurface_[[25,1,5]]: name 'PyMatchingDecoder' is no
#   TransversalY         + ToricCode_3x3       : name 'PyMatchingDecoder' is no
#   TransversalY         + ToricCode_5x5       : Non-deterministic detectors
#   TransversalY         + XZZX_Surface_5      : name 'PyMatchingDecoder' is no
#   TransversalY         + ToricCode4D_2       : Failed to decompose errors int
#   TransversalY         + ToricCode4D_3       : Failed to decompose errors int
#   TransversalY         + ToricCode3D_3x3x3   : Non-deterministic detectors
#   TransversalY         + ToricCode3D_4x4x4   : Non-deterministic detectors
#   TransversalY         + ToricCode3DFaces_3x3x3: Non-deterministic detectors
#   TransversalY         + HyperbolicSurfaceCode: name 'PyMatchingDecoder' is no
#   TransversalY         + TwistedToric_[[32,2,None]]: name 'PyMatchingDecoder' is no
#   TransversalY         + TwistedToric_4x4_[[32,2,None]]: name 'PyMatchingDecoder' is no
#   TransversalY         + ProjectivePlaneSurface_[[13,1,None]]: name 'PyMatchingDecoder' is no
#   TransversalY         + TriangularColour_d3 : name 'PyMatchingDecoder' is no
#   TransversalY         + TriangularColour_d5 : Failed to decompose errors int
#   TransversalY         + HexagonalColour_d2  : name 'PyMatchingDecoder' is no
#   TransversalY         + HexagonalColour_d3  : Non-deterministic detectors
#   TransversalY         + TruncatedTrihexColorCode: name 'PyMatchingDecoder' is no
#   TransversalY         + ColorCode3D_d3      : Non-deterministic detectors
#   TransversalY         + ColorCode3D_d5      : Non-deterministic detectors
#   TransversalY         + ColorCode3DPrism_2x3: Non-deterministic detectors
#   TransversalY         + TetrahedralColorCode: Non-deterministic detectors
#   TransversalY         + BallColorCode       : name 'PyMatchingDecoder' is no
#   TransversalY         + HyperbolicColorCode : name 'PyMatchingDecoder' is no
#   TransversalY         + GaugeColor_3        : Non-deterministic detectors
#   TransversalZ         + XZZX_Surface_3      : name 'PyMatchingDecoder' is no
#   TransversalZ         + LoopToricCode4D     : name 'PyMatchingDecoder' is no
#   TransversalZ         + Hamming_CSS_15      : name 'PyMatchingDecoder' is no
#   TransversalZ         + Code_832            : Failed to decompose errors int
#   TransversalZ         + Colour488_[[9,1,3]] : name 'PyMatchingDecoder' is no
#   TransversalZ         + QuantumTanner_4     : Code 'QuantumTannerCode' is no
#   TransversalZ         + BalancedProduct_5x5_G1: Code 'BalancedProductCode' is
#   TransversalZ         + FourQubit422        : name 'PyMatchingDecoder' is no
#   TransversalZ         + SteanCode713        : name 'PyMatchingDecoder' is no
#   TransversalZ         + ShorCode91          : name 'PyMatchingDecoder' is no
#   TransversalZ         + RotatedSurface_[[9,1,3]]: name 'PyMatchingDecoder' is no
#   TransversalZ         + RotatedSurface_[[25,1,5]]: name 'PyMatchingDecoder' is no
#   TransversalZ         + ToricCode_3x3       : name 'PyMatchingDecoder' is no
#   TransversalZ         + ToricCode_5x5       : Non-deterministic detectors
#   TransversalZ         + XZZX_Surface_5      : name 'PyMatchingDecoder' is no
#   TransversalZ         + ToricCode4D_2       : Failed to decompose errors int
#   TransversalZ         + ToricCode4D_3       : Failed to decompose errors int
#   TransversalZ         + ToricCode3D_3x3x3   : Non-deterministic detectors
#   TransversalZ         + ToricCode3D_4x4x4   : Non-deterministic detectors
#   TransversalZ         + ToricCode3DFaces_3x3x3: Non-deterministic detectors
#   TransversalZ         + HyperbolicSurfaceCode: name 'PyMatchingDecoder' is no
#   TransversalZ         + TwistedToric_[[32,2,None]]: name 'PyMatchingDecoder' is no
#   TransversalZ         + TwistedToric_4x4_[[32,2,None]]: name 'PyMatchingDecoder' is no
#   TransversalZ         + ProjectivePlaneSurface_[[13,1,None]]: name 'PyMatchingDecoder' is no
#   TransversalZ         + TriangularColour_d3 : name 'PyMatchingDecoder' is no
#   TransversalZ         + TriangularColour_d5 : Failed to decompose errors int
#   TransversalZ         + HexagonalColour_d2  : name 'PyMatchingDecoder' is no
#   TransversalZ         + HexagonalColour_d3  : Non-deterministic detectors
#   TransversalZ         + TruncatedTrihexColorCode: name 'PyMatchingDecoder' is no
#   TransversalZ         + ColorCode3D_d3      : Non-deterministic detectors
#   TransversalZ         + ColorCode3D_d5      : Non-deterministic detectors
#   TransversalZ         + ColorCode3DPrism_2x3: Non-deterministic detectors
#   TransversalZ         + TetrahedralColorCode: Non-deterministic detectors
#   TransversalZ         + BallColorCode       : name 'PyMatchingDecoder' is no
#   TransversalZ         + HyperbolicColorCode : name 'PyMatchingDecoder' is no
#   TransversalZ         + GaugeColor_3        : Non-deterministic detectors
#   TransversalCNOT      + XZZX_Surface_3      : name 'PyMatchingDecoder' is no
#   TransversalCNOT      + LoopToricCode4D     : Failed to decompose errors int
#   TransversalCNOT      + Hamming_CSS_15      : An error case in a composite e
#   TransversalCNOT      + Code_832            : Failed to decompose errors int
#   TransversalCNOT      + Colour488_[[9,1,3]] : name 'PyMatchingDecoder' is no
#   TransversalCNOT      + QuantumTanner_4     : Code 'QuantumTannerCode' is no
#   TransversalCNOT      + BalancedProduct_5x5_G1: Code 'BalancedProductCode' is
#   TransversalCNOT      + FourQubit422        : name 'PyMatchingDecoder' is no
#   TransversalCNOT      + SteanCode713        : Failed to decompose errors int
#   TransversalCNOT      + ShorCode91          : name 'PyMatchingDecoder' is no
#   TransversalCNOT      + RotatedSurface_[[9,1,3]]: name 'PyMatchingDecoder' is no
#   TransversalCNOT      + RotatedSurface_[[25,1,5]]: Failed to decompose errors int
#   TransversalCNOT      + ToricCode_3x3       : Failed to decompose errors int
#   TransversalCNOT      + ToricCode_5x5       : Non-deterministic detectors
#   TransversalCNOT      + XZZX_Surface_5      : name 'PyMatchingDecoder' is no
#   TransversalCNOT      + ToricCode4D_2       : An error case in a composite e
#   TransversalCNOT      + ToricCode4D_3       : An error case in a composite e
#   TransversalCNOT      + ToricCode3D_3x3x3   : Non-deterministic detectors
#   TransversalCNOT      + ToricCode3D_4x4x4   : Non-deterministic detectors
#   TransversalCNOT      + ToricCode3DFaces_3x3x3: Non-deterministic detectors
#   TransversalCNOT      + HyperbolicSurfaceCode: Failed to decompose errors int
#   TransversalCNOT      + TwistedToric_[[32,2,None]]: Failed to decompose errors int
#   TransversalCNOT      + TwistedToric_4x4_[[32,2,None]]: Failed to decompose errors int
#   TransversalCNOT      + ProjectivePlaneSurface_[[13,1,None]]: An error case in a composite e
#   TransversalCNOT      + TriangularColour_d3 : Failed to decompose errors int
#   TransversalCNOT      + TriangularColour_d5 : Failed to decompose errors int
#   TransversalCNOT      + HexagonalColour_d2  : name 'PyMatchingDecoder' is no
#   TransversalCNOT      + HexagonalColour_d3  : Non-deterministic detectors
#   TransversalCNOT      + TruncatedTrihexColorCode: Failed to decompose errors int
#   TransversalCNOT      + ColorCode3D_d3      : Non-deterministic detectors
#   TransversalCNOT      + ColorCode3D_d5      : Non-deterministic detectors
#   TransversalCNOT      + ColorCode3DPrism_2x3: Non-deterministic detectors
#   TransversalCNOT      + TetrahedralColorCode: Non-deterministic detectors
#   TransversalCNOT      + BallColorCode       : An error case in a composite e
#   TransversalCNOT      + HyperbolicColorCode : Failed to decompose errors int
#   TransversalCNOT      + GaugeColor_3        : Non-deterministic detectors
#   TransversalCZ        + XZZX_Surface_3      : name 'PyMatchingDecoder' is no
#   TransversalCZ        + LoopToricCode4D     : Failed to decompose errors int
#   TransversalCZ        + Hamming_CSS_15      : name 'PyMatchingDecoder' is no
#   TransversalCZ        + Code_832            : Failed to decompose errors int
#   TransversalCZ        + Colour488_[[9,1,3]] : name 'PyMatchingDecoder' is no
#   TransversalCZ        + QuantumTanner_4     : Code 'QuantumTannerCode' is no
#   TransversalCZ        + BalancedProduct_5x5_G1: Code 'BalancedProductCode' is
#   TransversalCZ        + FourQubit422        : name 'PyMatchingDecoder' is no
#   TransversalCZ        + SteanCode713        : name 'PyMatchingDecoder' is no
#   TransversalCZ        + ShorCode91          : name 'PyMatchingDecoder' is no
#   TransversalCZ        + RotatedSurface_[[9,1,3]]: name 'PyMatchingDecoder' is no
#   TransversalCZ        + RotatedSurface_[[25,1,5]]: Failed to decompose errors int
#   TransversalCZ        + ToricCode_3x3       : Failed to decompose errors int
#   TransversalCZ        + ToricCode_5x5       : Non-deterministic detectors
#   TransversalCZ        + XZZX_Surface_5      : name 'PyMatchingDecoder' is no
#   TransversalCZ        + ToricCode4D_2       : An error case in a composite e
#   TransversalCZ        + ToricCode4D_3       : An error case in a composite e
#   TransversalCZ        + ToricCode3D_3x3x3   : Non-deterministic detectors
#   TransversalCZ        + ToricCode3D_4x4x4   : Non-deterministic detectors
#   TransversalCZ        + ToricCode3DFaces_3x3x3: Non-deterministic detectors
#   TransversalCZ        + HyperbolicSurfaceCode: name 'PyMatchingDecoder' is no
#   TransversalCZ        + TwistedToric_[[32,2,None]]: Failed to decompose errors int
#   TransversalCZ        + TwistedToric_4x4_[[32,2,None]]: Failed to decompose errors int
#   TransversalCZ        + ProjectivePlaneSurface_[[13,1,None]]: name 'PyMatchingDecoder' is no
#   TransversalCZ        + TriangularColour_d3 : name 'PyMatchingDecoder' is no
#   TransversalCZ        + TriangularColour_d5 : Failed to decompose errors int
#   TransversalCZ        + HexagonalColour_d2  : name 'PyMatchingDecoder' is no
#   TransversalCZ        + HexagonalColour_d3  : Non-deterministic detectors
#   TransversalCZ        + TruncatedTrihexColorCode: Failed to decompose errors int
#   TransversalCZ        + ColorCode3D_d3      : Non-deterministic detectors
#   TransversalCZ        + ColorCode3D_d5      : Non-deterministic detectors
#   TransversalCZ        + ColorCode3DPrism_2x3: Non-deterministic detectors
#   TransversalCZ        + TetrahedralColorCode: Non-deterministic detectors
#   TransversalCZ        + BallColorCode       : name 'PyMatchingDecoder' is no
#   TransversalCZ        + HyperbolicColorCode : Failed to decompose errors int
#   TransversalCZ        + GaugeColor_3        : Non-deterministic detectors
#   TransversalSWAP      + XZZX_Surface_3      : name 'PyMatchingDecoder' is no
#   TransversalSWAP      + LoopToricCode4D     : Failed to decompose errors int
#   TransversalSWAP      + Hamming_CSS_15      : name 'PyMatchingDecoder' is no
#   TransversalSWAP      + Code_832            : Failed to decompose errors int
#   TransversalSWAP      + Colour488_[[9,1,3]] : name 'PyMatchingDecoder' is no
#   TransversalSWAP      + QuantumTanner_4     : Code 'QuantumTannerCode' is no
#   TransversalSWAP      + BalancedProduct_5x5_G1: Code 'BalancedProductCode' is
#   TransversalSWAP      + FourQubit422        : name 'PyMatchingDecoder' is no
#   TransversalSWAP      + SteanCode713        : name 'PyMatchingDecoder' is no
#   TransversalSWAP      + ShorCode91          : name 'PyMatchingDecoder' is no
#   TransversalSWAP      + RotatedSurface_[[9,1,3]]: name 'PyMatchingDecoder' is no
#   TransversalSWAP      + RotatedSurface_[[25,1,5]]: Failed to decompose errors int
#   TransversalSWAP      + ToricCode_3x3       : Failed to decompose errors int
#   TransversalSWAP      + ToricCode_5x5       : Non-deterministic detectors
#   TransversalSWAP      + XZZX_Surface_5      : name 'PyMatchingDecoder' is no
#   TransversalSWAP      + ToricCode4D_2       : An error case in a composite e
#   TransversalSWAP      + ToricCode4D_3       : An error case in a composite e
#   TransversalSWAP      + ToricCode3D_3x3x3   : Non-deterministic detectors
#   TransversalSWAP      + ToricCode3D_4x4x4   : Non-deterministic detectors
#   TransversalSWAP      + ToricCode3DFaces_3x3x3: Non-deterministic detectors
#   TransversalSWAP      + HyperbolicSurfaceCode: name 'PyMatchingDecoder' is no
#   TransversalSWAP      + TwistedToric_[[32,2,None]]: Failed to decompose errors int
#   TransversalSWAP      + TwistedToric_4x4_[[32,2,None]]: Failed to decompose errors int
#   TransversalSWAP      + ProjectivePlaneSurface_[[13,1,None]]: name 'PyMatchingDecoder' is no
#   TransversalSWAP      + TriangularColour_d3 : name 'PyMatchingDecoder' is no
#   TransversalSWAP      + TriangularColour_d5 : Failed to decompose errors int
#   TransversalSWAP      + HexagonalColour_d2  : name 'PyMatchingDecoder' is no
#   TransversalSWAP      + HexagonalColour_d3  : Non-deterministic detectors
#   TransversalSWAP      + TruncatedTrihexColorCode: Failed to decompose errors int
#   TransversalSWAP      + ColorCode3D_d3      : Non-deterministic detectors
#   TransversalSWAP      + ColorCode3D_d5      : Non-deterministic detectors
#   TransversalSWAP      + ColorCode3DPrism_2x3: Non-deterministic detectors
#   TransversalSWAP      + TetrahedralColorCode: Non-deterministic detectors
#   TransversalSWAP      + BallColorCode       : name 'PyMatchingDecoder' is no
#   TransversalSWAP      + HyperbolicColorCode : Failed to decompose errors int
#   TransversalSWAP      + GaugeColor_3        : Non-deterministic detectors
#   TeleportedH          + XZZX_Surface_3      : name 'PyMatchingDecoder' is no
#   TeleportedH          + LoopToricCode4D     : name 'PyMatchingDecoder' is no
#   TeleportedH          + Hamming_CSS_15      : name 'PyMatchingDecoder' is no
#   TeleportedH          + Code_832            : name 'PyMatchingDecoder' is no
#   TeleportedH          + Colour488_[[9,1,3]] : name 'PyMatchingDecoder' is no
#   TeleportedH          + QuantumTanner_4     : Code 'QuantumTannerCode' is no
#   TeleportedH          + BalancedProduct_5x5_G1: Code 'BalancedProductCode' is
#   TeleportedH          + FourQubit422        : name 'PyMatchingDecoder' is no
#   TeleportedH          + SteanCode713        : name 'PyMatchingDecoder' is no
#   TeleportedH          + ShorCode91          : name 'PyMatchingDecoder' is no
#   TeleportedH          + RotatedSurface_[[9,1,3]]: name 'PyMatchingDecoder' is no
#   TeleportedH          + RotatedSurface_[[25,1,5]]: name 'PyMatchingDecoder' is no
#   TeleportedH          + ToricCode_3x3       : name 'PyMatchingDecoder' is no
#   TeleportedH          + ToricCode_5x5       : Non-deterministic detectors
#   TeleportedH          + XZZX_Surface_5      : name 'PyMatchingDecoder' is no
#   TeleportedH          + ToricCode4D_2       : Failed to decompose errors int
#   TeleportedH          + ToricCode4D_3       : Failed to decompose errors int
#   TeleportedH          + ToricCode3D_3x3x3   : Non-deterministic detectors
#   TeleportedH          + ToricCode3D_4x4x4   : Non-deterministic detectors
#   TeleportedH          + ToricCode3DFaces_3x3x3: Non-deterministic detectors
#   TeleportedH          + HyperbolicSurfaceCode: name 'PyMatchingDecoder' is no
#   TeleportedH          + TwistedToric_[[32,2,None]]: name 'PyMatchingDecoder' is no
#   TeleportedH          + TwistedToric_4x4_[[32,2,None]]: name 'PyMatchingDecoder' is no
#   TeleportedH          + ProjectivePlaneSurface_[[13,1,None]]: name 'PyMatchingDecoder' is no
#   TeleportedH          + TriangularColour_d3 : name 'PyMatchingDecoder' is no
#   TeleportedH          + TriangularColour_d5 : name 'PyMatchingDecoder' is no
#   TeleportedH          + HexagonalColour_d2  : name 'PyMatchingDecoder' is no
#   TeleportedH          + HexagonalColour_d3  : Non-deterministic detectors
#   TeleportedH          + TruncatedTrihexColorCode: name 'PyMatchingDecoder' is no
#   TeleportedH          + ColorCode3D_d3      : Non-deterministic detectors
#   TeleportedH          + ColorCode3D_d5      : Non-deterministic detectors
#   TeleportedH          + ColorCode3DPrism_2x3: Non-deterministic detectors
#   TeleportedH          + TetrahedralColorCode: Non-deterministic detectors
#   TeleportedH          + BallColorCode       : name 'PyMatchingDecoder' is no
#   TeleportedH          + HyperbolicColorCode : name 'PyMatchingDecoder' is no
#   TeleportedH          + GaugeColor_3        : Non-deterministic detectors
#   TeleportedIdentity   + XZZX_Surface_3      : name 'PyMatchingDecoder' is no
#   TeleportedIdentity   + LoopToricCode4D     : name 'PyMatchingDecoder' is no
#   TeleportedIdentity   + Hamming_CSS_15      : name 'PyMatchingDecoder' is no
#   TeleportedIdentity   + Code_832            : name 'PyMatchingDecoder' is no
#   TeleportedIdentity   + Colour488_[[9,1,3]] : name 'PyMatchingDecoder' is no
#   TeleportedIdentity   + QuantumTanner_4     : Code 'QuantumTannerCode' is no
#   TeleportedIdentity   + BalancedProduct_5x5_G1: Code 'BalancedProductCode' is
#   TeleportedIdentity   + FourQubit422        : name 'PyMatchingDecoder' is no
#   TeleportedIdentity   + SteanCode713        : name 'PyMatchingDecoder' is no
#   TeleportedIdentity   + ShorCode91          : name 'PyMatchingDecoder' is no
#   TeleportedIdentity   + RotatedSurface_[[9,1,3]]: name 'PyMatchingDecoder' is no
#   TeleportedIdentity   + RotatedSurface_[[25,1,5]]: name 'PyMatchingDecoder' is no
#   TeleportedIdentity   + ToricCode_3x3       : name 'PyMatchingDecoder' is no
#   TeleportedIdentity   + ToricCode_5x5       : Non-deterministic detectors
#   TeleportedIdentity   + XZZX_Surface_5      : name 'PyMatchingDecoder' is no
#   TeleportedIdentity   + ToricCode4D_2       : Failed to decompose errors int
#   TeleportedIdentity   + ToricCode4D_3       : Failed to decompose errors int
#   TeleportedIdentity   + ToricCode3D_3x3x3   : Non-deterministic detectors
#   TeleportedIdentity   + ToricCode3D_4x4x4   : Non-deterministic detectors
#   TeleportedIdentity   + ToricCode3DFaces_3x3x3: Non-deterministic detectors
#   TeleportedIdentity   + HyperbolicSurfaceCode: name 'PyMatchingDecoder' is no
#   TeleportedIdentity   + TwistedToric_[[32,2,None]]: name 'PyMatchingDecoder' is no
#   TeleportedIdentity   + TwistedToric_4x4_[[32,2,None]]: name 'PyMatchingDecoder' is no
#   TeleportedIdentity   + ProjectivePlaneSurface_[[13,1,None]]: name 'PyMatchingDecoder' is no
#   TeleportedIdentity   + TriangularColour_d3 : name 'PyMatchingDecoder' is no
#   TeleportedIdentity   + TriangularColour_d5 : name 'PyMatchingDecoder' is no
#   TeleportedIdentity   + HexagonalColour_d2  : name 'PyMatchingDecoder' is no
#   TeleportedIdentity   + HexagonalColour_d3  : Non-deterministic detectors
#   TeleportedIdentity   + TruncatedTrihexColorCode: name 'PyMatchingDecoder' is no
#   TeleportedIdentity   + ColorCode3D_d3      : Non-deterministic detectors
#   TeleportedIdentity   + ColorCode3D_d5      : Non-deterministic detectors
# ...
#   TeleportedIdentity   + ToricCode_5x5       : Non-deterministic detectors
#   TeleportedIdentity   + XZZX_Surface_5      : name 'PyMatchingDecoder' is no
#   TeleportedIdentity   + ToricCode4D_2       : Failed to decompose errors int
#   TeleportedIdentity   + ToricCode4D_3       : Failed to decompose errors int
#   TeleportedIdentity   + ToricCode3D_3x3x3   : Non-deterministic detectors
#   TeleportedIdentity   + ToricCode3D_4x4x4   : Non-deterministic detectors
#   TeleportedIdentity   + ToricCode3DFaces_3x3x3: Non-deterministic detectors
#   TeleportedIdentity   + HyperbolicSurfaceCode: name 'PyMatchingDecoder' is no
#   TeleportedIdentity   + TwistedToric_[[32,2,None]]: name 'PyMatchingDecoder' is no
#   TeleportedIdentity   + TwistedToric_4x4_[[32,2,None]]: name 'PyMatchingDecoder' is no
#   TeleportedIdentity   + ProjectivePlaneSurface_[[13,1,None]]: name 'PyMatchingDecoder' is no
#   TeleportedIdentity   + TriangularColour_d3 : name 'PyMatchingDecoder' is no
#   TeleportedIdentity   + TriangularColour_d5 : name 'PyMatchingDecoder' is no
#   TeleportedIdentity   + HexagonalColour_d2  : name 'PyMatchingDecoder' is no
#   TeleportedIdentity   + HexagonalColour_d3  : Non-deterministic detectors
#   TeleportedIdentity   + TruncatedTrihexColorCode: name 'PyMatchingDecoder' is no
#   TeleportedIdentity   + ColorCode3D_d3      : Non-deterministic detectors
#   TeleportedIdentity   + ColorCode3D_d5      : Non-deterministic detectors
#   TeleportedIdentity   + ColorCode3DPrism_2x3: Non-deterministic detectors
#   TeleportedIdentity   + TetrahedralColorCode: Non-deterministic detectors
#   TeleportedIdentity   + BallColorCode       : name 'PyMatchingDecoder' is no
#   TeleportedIdentity   + HyperbolicColorCode : name 'PyMatchingDecoder' is no
#   TeleportedIdentity   + GaugeColor_3        : Non-deterministic detectors
#   BellTeleportedS      + XZZX_Surface_3      : name 'PyMatchingDecoder' is no
#   BellTeleportedS      + LoopToricCode4D     : name 'PyMatchingDecoder' is no
#   BellTeleportedS      + Hamming_CSS_15      : name 'PyMatchingDecoder' is no
#   BellTeleportedS      + Code_832            : name 'PyMatchingDecoder' is no
#   BellTeleportedS      + Colour488_[[9,1,3]] : name 'PyMatchingDecoder' is no
#   BellTeleportedS      + QuantumTanner_4     : Code 'QuantumTannerCode' is no
#   BellTeleportedS      + BalancedProduct_5x5_G1: Code 'BalancedProductCode' is
#   BellTeleportedS      + FourQubit422        : name 'PyMatchingDecoder' is no
#   BellTeleportedS      + SteanCode713        : name 'PyMatchingDecoder' is no
#   BellTeleportedS      + ShorCode91          : name 'PyMatchingDecoder' is no
#   BellTeleportedS      + RotatedSurface_[[9,1,3]]: name 'PyMatchingDecoder' is no
#   BellTeleportedS      + RotatedSurface_[[25,1,5]]: name 'PyMatchingDecoder' is no
#   BellTeleportedS      + ToricCode_3x3       : name 'PyMatchingDecoder' is no
#   BellTeleportedS      + ToricCode_5x5       : Non-deterministic detectors
#   BellTeleportedS      + XZZX_Surface_5      : name 'PyMatchingDecoder' is no
#   BellTeleportedS      + ToricCode4D_2       : Failed to decompose errors int
#   BellTeleportedS      + ToricCode4D_3       : Failed to decompose errors int
#   BellTeleportedS      + ToricCode3D_3x3x3   : Non-deterministic detectors
#   BellTeleportedS      + ToricCode3D_4x4x4   : Non-deterministic detectors
#   BellTeleportedS      + ToricCode3DFaces_3x3x3: Non-deterministic detectors
#   BellTeleportedS      + HyperbolicSurfaceCode: name 'PyMatchingDecoder' is no
#   BellTeleportedS      + TwistedToric_[[32,2,None]]: name 'PyMatchingDecoder' is no
#   BellTeleportedS      + TwistedToric_4x4_[[32,2,None]]: name 'PyMatchingDecoder' is no
#   BellTeleportedS      + ProjectivePlaneSurface_[[13,1,None]]: name 'PyMatchingDecoder' is no
#   BellTeleportedS      + TriangularColour_d3 : name 'PyMatchingDecoder' is no
#   BellTeleportedS      + TriangularColour_d5 : name 'PyMatchingDecoder' is no
#   BellTeleportedS      + HexagonalColour_d2  : name 'PyMatchingDecoder' is no
#   BellTeleportedS      + HexagonalColour_d3  : Non-deterministic detectors
#   BellTeleportedS      + TruncatedTrihexColorCode: name 'PyMatchingDecoder' is no
#   BellTeleportedS      + ColorCode3D_d3      : Non-deterministic detectors
#   BellTeleportedS      + ColorCode3D_d5      : Non-deterministic detectors
#   BellTeleportedS      + ColorCode3DPrism_2x3: Non-deterministic detectors
#   BellTeleportedS      + TetrahedralColorCode: Non-deterministic detectors
#   BellTeleportedS      + BallColorCode       : name 'PyMatchingDecoder' is no
#   BellTeleportedS      + HyperbolicColorCode : name 'PyMatchingDecoder' is no
#   BellTeleportedS      + GaugeColor_3        : Non-deterministic detectors
#   BellTeleportedSDag   + XZZX_Surface_3      : name 'PyMatchingDecoder' is no
#   BellTeleportedSDag   + LoopToricCode4D     : name 'PyMatchingDecoder' is no
#   BellTeleportedSDag   + Hamming_CSS_15      : name 'PyMatchingDecoder' is no
#   BellTeleportedSDag   + Code_832            : name 'PyMatchingDecoder' is no
#   BellTeleportedSDag   + Colour488_[[9,1,3]] : name 'PyMatchingDecoder' is no
#   BellTeleportedSDag   + QuantumTanner_4     : Code 'QuantumTannerCode' is no
#   BellTeleportedSDag   + BalancedProduct_5x5_G1: Code 'BalancedProductCode' is
#   BellTeleportedSDag   + FourQubit422        : name 'PyMatchingDecoder' is no
#   BellTeleportedSDag   + SteanCode713        : name 'PyMatchingDecoder' is no
#   BellTeleportedSDag   + ShorCode91          : name 'PyMatchingDecoder' is no
#   BellTeleportedSDag   + RotatedSurface_[[9,1,3]]: name 'PyMatchingDecoder' is no
#   BellTeleportedSDag   + RotatedSurface_[[25,1,5]]: name 'PyMatchingDecoder' is no
#   BellTeleportedSDag   + ToricCode_3x3       : name 'PyMatchingDecoder' is no
#   BellTeleportedSDag   + ToricCode_5x5       : Non-deterministic detectors
#   BellTeleportedSDag   + XZZX_Surface_5      : name 'PyMatchingDecoder' is no
#   BellTeleportedSDag   + ToricCode4D_2       : Failed to decompose errors int
#   BellTeleportedSDag   + ToricCode4D_3       : Failed to decompose errors int
#   BellTeleportedSDag   + ToricCode3D_3x3x3   : Non-deterministic detectors
#   BellTeleportedSDag   + ToricCode3D_4x4x4   : Non-deterministic detectors
#   BellTeleportedSDag   + ToricCode3DFaces_3x3x3: Non-deterministic detectors
#   BellTeleportedSDag   + HyperbolicSurfaceCode: name 'PyMatchingDecoder' is no
#   BellTeleportedSDag   + TwistedToric_[[32,2,None]]: name 'PyMatchingDecoder' is no
#   BellTeleportedSDag   + TwistedToric_4x4_[[32,2,None]]: name 'PyMatchingDecoder' is no
#   BellTeleportedSDag   + ProjectivePlaneSurface_[[13,1,None]]: name 'PyMatchingDecoder' is no
#   BellTeleportedSDag   + TriangularColour_d3 : name 'PyMatchingDecoder' is no
#   BellTeleportedSDag   + TriangularColour_d5 : name 'PyMatchingDecoder' is no
#   BellTeleportedSDag   + HexagonalColour_d2  : name 'PyMatchingDecoder' is no
#   BellTeleportedSDag   + HexagonalColour_d3  : Non-deterministic detectors
#   BellTeleportedSDag   + TruncatedTrihexColorCode: name 'PyMatchingDecoder' is no
#   BellTeleportedSDag   + ColorCode3D_d3      : Non-deterministic detectors
#   BellTeleportedSDag   + ColorCode3D_d5      : Non-deterministic detectors
#   BellTeleportedSDag   + ColorCode3DPrism_2x3: Non-deterministic detectors
#   BellTeleportedSDag   + TetrahedralColorCode: Non-deterministic detectors
#   BellTeleportedSDag   + BallColorCode       : name 'PyMatchingDecoder' is no
#   BellTeleportedSDag   + HyperbolicColorCode : name 'PyMatchingDecoder' is no
#   BellTeleportedSDag   + GaugeColor_3        : Non-deterministic detectors
#   LatticeZZMerge       + XZZX_Surface_3      : name 'PyMatchingDecoder' is no
#   LatticeZZMerge       + LoopToricCode4D     : Failed to decompose errors int
#   LatticeZZMerge       + Hamming_CSS_15      : name 'PyMatchingDecoder' is no
#   LatticeZZMerge       + Code_832            : Failed to decompose errors int
#   LatticeZZMerge       + Colour488_[[9,1,3]] : name 'PyMatchingDecoder' is no
#   LatticeZZMerge       + QuantumTanner_4     : Code 'QuantumTannerCode' is no
#   LatticeZZMerge       + BalancedProduct_5x5_G1: Code 'BalancedProductCode' is
#   LatticeZZMerge       + FourQubit422        : name 'PyMatchingDecoder' is no
#   LatticeZZMerge       + SteanCode713        : name 'PyMatchingDecoder' is no
#   LatticeZZMerge       + ShorCode91          : name 'PyMatchingDecoder' is no
#   LatticeZZMerge       + RotatedSurface_[[9,1,3]]: name 'PyMatchingDecoder' is no
#   LatticeZZMerge       + RotatedSurface_[[25,1,5]]: Failed to decompose errors int
#   LatticeZZMerge       + ToricCode_3x3       : Failed to decompose errors int
#   LatticeZZMerge       + ToricCode_5x5       : Non-deterministic detectors
#   LatticeZZMerge       + XZZX_Surface_5      : name 'PyMatchingDecoder' is no
#   LatticeZZMerge       + ToricCode4D_2       : An error case in a composite e
#   LatticeZZMerge       + ToricCode4D_3       : An error case in a composite e
#   LatticeZZMerge       + ToricCode3D_3x3x3   : Non-deterministic detectors
#   LatticeZZMerge       + ToricCode3D_4x4x4   : Non-deterministic detectors
#   LatticeZZMerge       + ToricCode3DFaces_3x3x3: Non-deterministic detectors
#   LatticeZZMerge       + HyperbolicSurfaceCode: name 'PyMatchingDecoder' is no
#   LatticeZZMerge       + TwistedToric_[[32,2,None]]: Failed to decompose errors int
#   LatticeZZMerge       + TwistedToric_4x4_[[32,2,None]]: Failed to decompose errors int
#   LatticeZZMerge       + ProjectivePlaneSurface_[[13,1,None]]: name 'PyMatchingDecoder' is no
#   LatticeZZMerge       + TriangularColour_d3 : name 'PyMatchingDecoder' is no
#   LatticeZZMerge       + TriangularColour_d5 : Failed to decompose errors int
#   LatticeZZMerge       + HexagonalColour_d2  : name 'PyMatchingDecoder' is no
#   LatticeZZMerge       + HexagonalColour_d3  : Non-deterministic detectors
#   LatticeZZMerge       + TruncatedTrihexColorCode: Failed to decompose errors int
#   LatticeZZMerge       + ColorCode3D_d3      : Non-deterministic detectors
#   LatticeZZMerge       + ColorCode3D_d5      : Non-deterministic detectors
#   LatticeZZMerge       + ColorCode3DPrism_2x3: Non-deterministic detectors
#   LatticeZZMerge       + TetrahedralColorCode: Non-deterministic detectors
#   LatticeZZMerge       + BallColorCode       : name 'PyMatchingDecoder' is no
#   LatticeZZMerge       + HyperbolicColorCode : Failed to decompose errors int
#   LatticeZZMerge       + GaugeColor_3        : Non-deterministic detectors
#   LatticeXXMerge       + XZZX_Surface_3      : name 'PyMatchingDecoder' is no
#   LatticeXXMerge       + LoopToricCode4D     : name 'PyMatchingDecoder' is no
#   LatticeXXMerge       + Hamming_CSS_15      : name 'PyMatchingDecoder' is no
#   LatticeXXMerge       + Code_832            : Failed to decompose errors int
#   LatticeXXMerge       + Colour488_[[9,1,3]] : name 'PyMatchingDecoder' is no
#   LatticeXXMerge       + QuantumTanner_4     : Code 'QuantumTannerCode' is no
#   LatticeXXMerge       + BalancedProduct_5x5_G1: Code 'BalancedProductCode' is
#   LatticeXXMerge       + FourQubit422        : name 'PyMatchingDecoder' is no
#   LatticeXXMerge       + SteanCode713        : name 'PyMatchingDecoder' is no
#   LatticeXXMerge       + ShorCode91          : name 'PyMatchingDecoder' is no
#   LatticeXXMerge       + RotatedSurface_[[9,1,3]]: name 'PyMatchingDecoder' is no
#   LatticeXXMerge       + RotatedSurface_[[25,1,5]]: name 'PyMatchingDecoder' is no
#   LatticeXXMerge       + ToricCode_3x3       : name 'PyMatchingDecoder' is no
#   LatticeXXMerge       + ToricCode_5x5       : Non-deterministic detectors
#   LatticeXXMerge       + XZZX_Surface_5      : name 'PyMatchingDecoder' is no
#   LatticeXXMerge       + ToricCode4D_2       : Failed to decompose errors int
#   LatticeXXMerge       + ToricCode4D_3       : Failed to decompose errors int
#   LatticeXXMerge       + ToricCode3D_3x3x3   : Non-deterministic detectors
#   LatticeXXMerge       + ToricCode3D_4x4x4   : Non-deterministic detectors
#   LatticeXXMerge       + ToricCode3DFaces_3x3x3: Non-deterministic detectors
#   LatticeXXMerge       + HyperbolicSurfaceCode: name 'PyMatchingDecoder' is no
#   LatticeXXMerge       + TwistedToric_[[32,2,None]]: name 'PyMatchingDecoder' is no
#   LatticeXXMerge       + TwistedToric_4x4_[[32,2,None]]: name 'PyMatchingDecoder' is no
#   LatticeXXMerge       + ProjectivePlaneSurface_[[13,1,None]]: name 'PyMatchingDecoder' is no
#   LatticeXXMerge       + TriangularColour_d3 : name 'PyMatchingDecoder' is no
#   LatticeXXMerge       + TriangularColour_d5 : Failed to decompose errors int
#   LatticeXXMerge       + HexagonalColour_d2  : name 'PyMatchingDecoder' is no
#   LatticeXXMerge       + HexagonalColour_d3  : Non-deterministic detectors
#   LatticeXXMerge       + TruncatedTrihexColorCode: name 'PyMatchingDecoder' is no
#   LatticeXXMerge       + ColorCode3D_d3      : Non-deterministic detectors
#   LatticeXXMerge       + ColorCode3D_d5      : Non-deterministic detectors
#   LatticeXXMerge       + ColorCode3DPrism_2x3: Non-deterministic detectors
#   LatticeXXMerge       + TetrahedralColorCode: Non-deterministic detectors
#   LatticeXXMerge       + BallColorCode       : name 'PyMatchingDecoder' is no
#   LatticeXXMerge       + HyperbolicColorCode : name 'PyMatchingDecoder' is no
#   LatticeXXMerge       + GaugeColor_3        : Non-deterministic detectors
#   SurgeryCNOT          + XZZX_Surface_3      : name 'PyMatchingDecoder' is no
#   SurgeryCNOT          + LoopToricCode4D     : Failed to decompose errors int
#   SurgeryCNOT          + Hamming_CSS_15      : name 'PyMatchingDecoder' is no
#   SurgeryCNOT          + Code_832            : Failed to decompose errors int
#   SurgeryCNOT          + Colour488_[[9,1,3]] : name 'PyMatchingDecoder' is no
#   SurgeryCNOT          + QuantumTanner_4     : Code 'QuantumTannerCode' is no
#   SurgeryCNOT          + BalancedProduct_5x5_G1: Code 'BalancedProductCode' is
#   SurgeryCNOT          + FourQubit422        : name 'PyMatchingDecoder' is no
#   SurgeryCNOT          + SteanCode713        : name 'PyMatchingDecoder' is no
#   SurgeryCNOT          + ShorCode91          : name 'PyMatchingDecoder' is no
#   SurgeryCNOT          + RotatedSurface_[[9,1,3]]: name 'PyMatchingDecoder' is no
#   SurgeryCNOT          + RotatedSurface_[[25,1,5]]: name 'PyMatchingDecoder' is no
#   SurgeryCNOT          + ToricCode_3x3       : Failed to decompose errors int
#   SurgeryCNOT          + ToricCode_5x5       : Non-deterministic detectors
#   SurgeryCNOT          + XZZX_Surface_5      : name 'PyMatchingDecoder' is no
#   SurgeryCNOT          + ToricCode4D_2       : An error case in a composite e
#   SurgeryCNOT          + ToricCode4D_3       : An error case in a composite e
#   SurgeryCNOT          + ToricCode3D_3x3x3   : Non-deterministic detectors
#   SurgeryCNOT          + ToricCode3D_4x4x4   : Non-deterministic detectors
#   SurgeryCNOT          + ToricCode3DFaces_3x3x3: Non-deterministic detectors
#   SurgeryCNOT          + HyperbolicSurfaceCode: name 'PyMatchingDecoder' is no
#   SurgeryCNOT          + TwistedToric_[[32,2,None]]: Failed to decompose errors int
#   SurgeryCNOT          + TwistedToric_4x4_[[32,2,None]]: Failed to decompose errors int
#   SurgeryCNOT          + ProjectivePlaneSurface_[[13,1,None]]: name 'PyMatchingDecoder' is no
#   SurgeryCNOT          + TriangularColour_d3 : name 'PyMatchingDecoder' is no
#   SurgeryCNOT          + TriangularColour_d5 : Failed to decompose errors int
#   SurgeryCNOT          + HexagonalColour_d2  : name 'PyMatchingDecoder' is no
#   SurgeryCNOT          + HexagonalColour_d3  : Non-deterministic detectors
#   SurgeryCNOT          + TruncatedTrihexColorCode: Failed to decompose errors int
#   SurgeryCNOT          + ColorCode3D_d3      : Non-deterministic detectors
#   SurgeryCNOT          + ColorCode3D_d5      : Non-deterministic detectors
#   SurgeryCNOT          + ColorCode3DPrism_2x3: Non-deterministic detectors
#   SurgeryCNOT          + TetrahedralColorCode: Non-deterministic detectors
#   SurgeryCNOT          + BallColorCode       : name 'PyMatchingDecoder' is no
#   SurgeryCNOT          + HyperbolicColorCode : Failed to decompose errors int
#   SurgeryCNOT          + GaugeColor_3        : Non-deterministic detectors

# %%
# ==========================================================================
# COMPREHENSIVE TEST: Code × Decoder Matrix for Each Gadget
# ==========================================================================
# This cell runs all tests and stores results in `all_gadget_results`

from qectostim.decoders import PyMatchingDecoder

# Select decoders to test (exclude problematic ones)
TEST_DECODERS = {k: v for k, v in decoder_classes.items() 
                 if k not in ['Chromobius', 'Concatenated', 'FlatConcat']}  # These have special requirements

print(f"Testing with {len(TEST_DECODERS)} decoders: {list(TEST_DECODERS.keys())}")
print(f"Testing on {len(TEST_CODES)} codes")
print(f"Testing {len(ALL_GADGETS)} gadgets")
total_combos = len(ALL_GADGETS) * len(TEST_CODES) * len(TEST_DECODERS)
print(f"Total test combinations: {len(ALL_GADGETS)} × {len(TEST_CODES)} × {len(TEST_DECODERS)} = {total_combos}")
print("\nRunning tests...")

def run_gadget_code_decoder_tests(
    gadget_name: str,
    gadget_class,
    gadget_kwargs: Dict,
    is_two_qubit: bool,
    test_codes: Dict,
    decoder_classes: Dict,
    shots: int = 1000,
) -> Dict:
    """
    Run Code × Decoder matrix for a single gadget.
    Returns results dict (no printing).
    """
    results = {}
    dec_names = list(decoder_classes.keys())
    
    for code_name, code in test_codes.items():
        results[code_name] = {}
        
        # First, try to build the circuit once (shared across decoders)
        circuit = None
        circuit_error = None
        dem = None
        det_samples = None
        obs_samples = None
        
        try:
            gadget = gadget_class(**gadget_kwargs)
            codes = [code, code] if is_two_qubit else [code]
            
            exp = FaultTolerantGadgetExperiment(
                codes=codes,
                gadget=gadget,
                noise_model=noise,
                num_rounds_before=2,
                num_rounds_after=2,
            )
            
            circuit = exp.to_stim()
            
            if circuit.num_detectors == 0:
                circuit_error = "No detectors"
            else:
                # Try to build DEM
                try:
                    dem = circuit.detector_error_model(decompose_errors=True)
                    sampler = circuit.compile_detector_sampler()
                    samples = sampler.sample(shots, append_observables=True)
                    det_samples = samples[:, :circuit.num_detectors]
                    obs_samples = samples[:, circuit.num_detectors:]
                except ValueError as e:
                    if "non-deterministic" in str(e).lower():
                        circuit_error = "DET_ERR"
                    else:
                        circuit_error = f"DEM: {str(e)[:20]}"
                        
        except ValueError as e:
            if "not supported" in str(e).lower() or "placeholder" in str(e).lower():
                circuit_error = "UNSUPPORTED"
            else:
                circuit_error = f"VAL: {str(e)[:15]}"
        except Exception as e:
            err_str = str(e).lower()
            if "non-clifford" in err_str:
                circuit_error = "NonCliff"
            else:
                circuit_error = f"ERR: {str(e)[:15]}"
        
        # If circuit failed, mark all decoders
        if circuit_error:
            for dec_name in dec_names:
                results[code_name][dec_name] = {'status': circuit_error, 'ler': None}
        else:
            # Test each decoder
            for dec_name, dec_class in decoder_classes.items():
                try:
                    is_compat, reason = check_decoder_compatibility(dec_name, code, code_name, circuit)
                    if not is_compat:
                        results[code_name][dec_name] = {'status': 'SKIP', 'ler': None, 'reason': reason}
                        continue
                    
                    decoder = dec_class(dem=dem)
                    predictions = decoder.decode_batch(det_samples)
                    if len(predictions.shape) == 1:
                        predictions = predictions.reshape(-1, 1)
                    
                    errors = np.any(predictions != obs_samples, axis=1)
                    ler = float(np.mean(errors))
                    
                    results[code_name][dec_name] = {'status': 'OK', 'ler': ler}
                    
                except Exception as e:
                    results[code_name][dec_name] = {'status': 'FAIL', 'ler': None, 'error': str(e)}
    
    return results


# ==========================================================================
# Run the full matrix for each gadget
# ==========================================================================
all_gadget_results = {}
skipped_gadgets = []

for i, (gadget_name, (cls, kwargs, is_two)) in enumerate(ALL_GADGETS.items()):
    # Skip known broken gadgets
    if gadget_name in KNOWN_BROKEN_GADGETS:
        skipped_gadgets.append((gadget_name, KNOWN_BROKEN_GADGETS[gadget_name]))
        continue
    
    print(f"  [{i+1}/{len(ALL_GADGETS)}] Testing {gadget_name}...", end=" ")
    start_time = time.time()
    
    all_gadget_results[gadget_name] = run_gadget_code_decoder_tests(
        gadget_name=gadget_name,
        gadget_class=cls,
        gadget_kwargs=kwargs,
        is_two_qubit=is_two,
        test_codes=TEST_CODES,
        decoder_classes=TEST_DECODERS,
        shots=1000,
    )
    
    elapsed = time.time() - start_time
    ok_count = sum(1 for c in all_gadget_results[gadget_name].values() 
                   for d in c.values() if d.get('status') == 'OK')
    total_count = len(TEST_CODES) * len(TEST_DECODERS)
    print(f"done ({elapsed:.1f}s) - {ok_count}/{total_count} OK")

print(f"\n✓ All tests complete! Results stored in `all_gadget_results`")
print(f"  Tested: {len(all_gadget_results)} gadgets")
print(f"  Skipped: {len(skipped_gadgets)} gadgets")
# Out:
# Testing with 10 decoders: ['PyMatching', 'FusionBlossom', 'BeliefMatching', 'BPOSD', 'Tesseract', 'UnionFind', 'MLE', 'Hypergraph', 'Hierarchical', 'SingleShot']
# Testing on 36 codes
# Testing 16 gadgets
# Total test combinations: 16 × 36 × 10 = 5760
#
# Running tests...
#   [1/16] Testing TransversalH... Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# done (52.5s) - 108/360 OK
#   [2/16] Testing TransversalS... done (52.5s) - 108/360 OK
#   [2/16] Testing TransversalS... Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# done (54.0s) - 100/360 OK
#   [4/16] Testing TransversalX... done (54.0s) - 100/360 OK
#   [4/16] Testing TransversalX... Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# done (74.9s) - 144/360 OK
#   [5/16] Testing TransversalY... done (74.9s) - 144/360 OK
#   [5/16] Testing TransversalY... Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# done (80.1s) - 144/360 OK
#   [6/16] Testing TransversalZ... done (80.1s) - 144/360 OK
#   [6/16] Testing TransversalZ... Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# done (70.4s) - 144/360 OK
#   [7/16] Testing TransversalCNOT... done (70.4s) - 144/360 OK
#   [7/16] Testing TransversalCNOT... Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# done (96.1s) - 50/360 OK
#   [8/16] Testing TransversalCZ... done (96.1s) - 50/360 OK
#   [8/16] Testing TransversalCZ... Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# done (110.9s) - 92/360 OK
#   [9/16] Testing TransversalSWAP... done (110.9s) - 92/360 OK
#   [9/16] Testing TransversalSWAP... Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# done (98.8s) - 92/360 OK
#   [10/16] Testing TeleportedH... done (98.8s) - 92/360 OK
#   [10/16] Testing TeleportedH... Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# done (96.8s) - 159/360 OK
#   [11/16] Testing TeleportedIdentity... done (96.8s) - 159/360 OK
#   [11/16] Testing TeleportedIdentity... Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# done (84.3s) - 159/360 OK
#   [12/16] Testing BellTeleportedS... done (84.3s) - 159/360 OK
#   [12/16] Testing BellTeleportedS... Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# done (131.0s) - 155/360 OK
#   [13/16] Testing BellTeleportedSDag... done (131.0s) - 155/360 OK
#   [13/16] Testing BellTeleportedSDag... Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# done (129.9s) - 155/360 OK
#   [14/16] Testing LatticeZZMerge... done (129.9s) - 155/360 OK
#   [14/16] Testing LatticeZZMerge... Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# done (105.6s) - 92/360 OK
#   [15/16] Testing LatticeXXMerge... done (105.6s) - 92/360 OK
#   [15/16] Testing LatticeXXMerge... Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# done (119.1s) - 141/360 OK
#   [16/16] Testing SurgeryCNOT... done (119.1s) - 141/360 OK
#   [16/16] Testing SurgeryCNOT... Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# Warning: the circuit has errors that do not flip any detectors
# done (117.5s) - 99/360 OK
#
# ✓ All tests complete! Results stored in `all_gadget_results`
#   Tested: 15 gadgets
#   Skipped: 1 gadgets
# done (117.5s) - 99/360 OK
#
# ✓ All tests complete! Results stored in `all_gadget_results`
#   Tested: 15 gadgets
#   Skipped: 1 gadgets

# %%
# ==========================================================================
# DISPLAY RESULTS: Code × Decoder Matrix for Each Gadget
# ==========================================================================
# This cell pretty-prints the results from `all_gadget_results`

def display_gadget_matrix(gadget_name: str, results: Dict, decoder_names: List[str]):
    """Pretty print a Code × Decoder matrix for one gadget."""
    code_names = list(results.keys())
    dec_display = [name[:10] for name in decoder_names]
    
    # Header
    header = f"{'Code':<18}"
    for dec in dec_display:
        header += f" | {dec:^10}"
    
    print(f"\n{'='*len(header)}")
    print(f"GADGET: {gadget_name}")
    print(f"{'='*len(header)}")
    print(header)
    print("-" * len(header))
    
    for code_name in code_names:
        row = f"{code_name[:18]:<18}"
        for dec_name in decoder_names:
            result = results[code_name].get(dec_name, {'status': '?', 'ler': None})
            status = result.get('status', '?')
            ler = result.get('ler')
            
            if status == 'OK' and ler is not None:
                cell = f"{ler:.4f}"
            else:
                cell = status[:10]
            row += f" | {cell:^10}"
        print(row)
    
    print("-" * len(header))
    
    # Summary
    ok_count = sum(1 for c in results.values() for d in c.values() if d.get('status') == 'OK')
    total = len(code_names) * len(decoder_names)
    print(f"Summary: {ok_count}/{total} OK ({100*ok_count/total:.0f}%)")


# Display each gadget's matrix
dec_names = list(TEST_DECODERS.keys())

for gadget_name, results in all_gadget_results.items():
    display_gadget_matrix(gadget_name, results, dec_names)

# Display skipped gadgets
if skipped_gadgets:
    print(f"\n{'='*60}")
    print("SKIPPED GADGETS")
    print(f"{'='*60}")
    for name, reason in skipped_gadgets:
        print(f"  {name:<25}: {reason}")

# ==========================================================================
# OVERALL SUMMARY
# ==========================================================================
print("\n" + "=" * 100)
print("OVERALL SUMMARY: All Gadgets × All Codes × All Decoders")
print("=" * 100)

# Aggregate statistics
status_counts = defaultdict(int)

for gadget_name, code_results in all_gadget_results.items():
    for code_name, dec_results in code_results.items():
        for dec_name, result in dec_results.items():
            status = result.get('status', 'FAIL')
            if status == 'OK':
                status_counts['OK'] += 1
            elif status == 'SKIP':
                status_counts['SKIP'] += 1
            elif status == 'DET_ERR':
                status_counts['DET_ERR'] += 1
            elif status == 'UNSUPPORTED':
                status_counts['UNSUPPORTED'] += 1
            elif status == 'NonCliff':
                status_counts['NonCliff'] += 1
            else:
                status_counts['FAIL'] += 1

total = sum(status_counts.values())
print(f"\nTotal test combinations: {total}")
print(f"  ✓ OK:          {status_counts['OK']:4d} ({100*status_counts['OK']/total:.1f}%)")
print(f"  ⚠ DET_ERR:     {status_counts['DET_ERR']:4d} ({100*status_counts['DET_ERR']/total:.1f}%) - Non-deterministic detectors")
print(f"  ⊘ UNSUPPORTED: {status_counts['UNSUPPORTED']:4d} ({100*status_counts['UNSUPPORTED']/total:.1f}%) - Code not supported")
print(f"  ~ SKIP:        {status_counts['SKIP']:4d} ({100*status_counts['SKIP']/total:.1f}%) - Decoder incompatible")
print(f"  ✗ FAIL:        {status_counts['FAIL']:4d} ({100*status_counts['FAIL']/total:.1f}%) - Decoder error")

# Per-gadget summary table
print("\n" + "-" * 80)
print("Per-Gadget Summary:")
print("-" * 80)
print(f"{'Gadget':<25} | {'OK':>6} | {'DET_ERR':>7} | {'FAIL':>6} | {'SKIP':>6} | {'Rate':>6}")
print("-" * 80)

for gadget_name, code_results in all_gadget_results.items():
    g_ok = sum(1 for c in code_results.values() for d in c.values() if d.get('status') == 'OK')
    g_det = sum(1 for c in code_results.values() for d in c.values() if d.get('status') == 'DET_ERR')
    g_fail = sum(1 for c in code_results.values() for d in c.values() if d.get('status') == 'FAIL')
    g_skip = sum(1 for c in code_results.values() for d in c.values() if d.get('status') == 'SKIP')
    g_total = sum(len(d) for d in code_results.values())
    rate = 100 * g_ok / g_total if g_total > 0 else 0
    print(f"{gadget_name:<25} | {g_ok:>6} | {g_det:>7} | {g_fail:>6} | {g_skip:>6} | {rate:>5.0f}%")

# Per-code summary table
print("\n" + "-" * 80)
print("Per-Code Summary:")
print("-" * 80)
print(f"{'Code':<25} | {'OK':>6} | {'DET_ERR':>7} | {'FAIL':>6} | {'SKIP':>6} | {'Rate':>6}")
print("-" * 80)

code_stats = defaultdict(lambda: defaultdict(int))
for gadget_name, code_results in all_gadget_results.items():
    for code_name, dec_results in code_results.items():
        for dec_name, result in dec_results.items():
            status = result.get('status', 'FAIL')
            if status == 'OK':
                code_stats[code_name]['OK'] += 1
            elif status == 'DET_ERR':
                code_stats[code_name]['DET_ERR'] += 1
            elif status == 'SKIP':
                code_stats[code_name]['SKIP'] += 1
            else:
                code_stats[code_name]['FAIL'] += 1
            code_stats[code_name]['total'] += 1

for code_name, stats in code_stats.items():
    rate = 100 * stats['OK'] / stats['total'] if stats['total'] > 0 else 0
    print(f"{code_name[:25]:<25} | {stats['OK']:>6} | {stats['DET_ERR']:>7} | {stats['FAIL']:>6} | {stats['SKIP']:>6} | {rate:>5.0f}%")

# Per-decoder summary table
print("\n" + "-" * 80)
print("Per-Decoder Summary:")
print("-" * 80)
print(f"{'Decoder':<15} | {'OK':>6} | {'DET_ERR':>7} | {'FAIL':>6} | {'SKIP':>6} | {'Rate':>6}")
print("-" * 80)

dec_stats = defaultdict(lambda: defaultdict(int))
for gadget_name, code_results in all_gadget_results.items():
    for code_name, dec_results in code_results.items():
        for dec_name, result in dec_results.items():
            status = result.get('status', 'FAIL')
            if status == 'OK':
                dec_stats[dec_name]['OK'] += 1
            elif status == 'DET_ERR':
                dec_stats[dec_name]['DET_ERR'] += 1
            elif status == 'SKIP':
                dec_stats[dec_name]['SKIP'] += 1
            else:
                dec_stats[dec_name]['FAIL'] += 1
            dec_stats[dec_name]['total'] += 1

for dec_name, stats in dec_stats.items():
    rate = 100 * stats['OK'] / stats['total'] if stats['total'] > 0 else 0
    print(f"{dec_name:<15} | {stats['OK']:>6} | {stats['DET_ERR']:>7} | {stats['FAIL']:>6} | {stats['SKIP']:>6} | {rate:>5.0f}%")
# Out:
# ====================================================================================================================================================
# GADGET: TransversalH
# ====================================================================================================================================================
# Code               | PyMatching | FusionBlos | BeliefMatc |   BPOSD    | Tesseract  | UnionFind  |    MLE     | Hypergraph | Hierarchic | SingleShot
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# XZZX_Surface_3     |   0.0080   |   0.0100   |   0.0100   |   0.0020   |   0.0000   |   0.0080   |   0.0010   |   0.0230   |    FAIL    |    FAIL
# LoopToricCode4D    | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# Hamming_CSS_15     |   0.0540   |   0.0450   |   0.0520   |   0.0150   |   0.0110   |   0.0540   |   0.0120   |   0.0870   |    FAIL    |    FAIL
# Code_832           |   0.0240   |   0.0420   |   0.0320   |   0.0180   |   0.0040   |   0.0240   |   0.0040   |   0.0240   |    FAIL    |    FAIL
# Colour488_[[9,1,3] |   0.0260   |   0.0290   |   0.0430   |   0.0290   |   0.0100   |   0.0260   |   0.0120   |   0.0260   |    FAIL    |    FAIL
# QuantumTanner_4    | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE
# BalancedProduct_5x | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE
# FourQubit422       |   0.0120   |   0.0130   |   0.0140   |   0.0140   |   0.0130   |   0.0120   |   0.0130   |   0.0120   |    FAIL    |    FAIL
# SteanCode713       |   0.0210   |   0.0200   |   0.0200   |   0.0050   |   0.0020   |   0.0210   |   0.0040   |   0.0240   |    FAIL    |    FAIL
# ShorCode91         |   0.0260   |   0.0440   |   0.0370   |   0.0310   |   0.0110   |   0.0260   |    SKIP    |   0.0370   |    FAIL    |    FAIL
# RotatedSurface_[[9 |   0.0110   |   0.0150   |   0.0130   |   0.0030   |   0.0020   |   0.0110   |   0.0030   |   0.0230   |    FAIL    |    FAIL
# RotatedSurface_[[2 | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# ToricCode_3x3      | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# ToricCode_5x5      |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# XZZX_Surface_5     |   0.0010   |   0.0240   |   0.0030   |   0.0000   |   0.0000   |   0.0010   |    SKIP    |   0.0310   |    FAIL    |    FAIL
# ToricCode4D_2      | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er
# ToricCode4D_3      | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er
# ToricCode3D_3x3x3  |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ToricCode3D_4x4x4  |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ToricCode3DFaces_3 |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# HyperbolicSurfaceC |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0000   |    FAIL    |    FAIL
# TwistedToric_[[32, | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# TwistedToric_4x4_[ | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# ProjectivePlaneSur |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0000   |    FAIL    |    FAIL
# TriangularColour_d |   0.0160   |   0.0210   |   0.0180   |   0.0040   |   0.0020   |   0.0160   |   0.0020   |   0.0260   |    FAIL    |    FAIL
# TriangularColour_d | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# HexagonalColour_d2 |   0.0000   |   0.0180   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0100   |    FAIL    |    FAIL
# HexagonalColour_d3 |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# TruncatedTrihexCol | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# ColorCode3D_d3     |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ColorCode3D_d5     |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ColorCode3DPrism_2 |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# TetrahedralColorCo |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# BallColorCode      |   0.0610   |   0.0840   |   0.0500   |   0.0160   |   0.0110   |   0.0610   |   0.0170   |   0.0970   |    FAIL    |    FAIL
# HyperbolicColorCod | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# GaugeColor_3       |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# Summary: 108/360 OK (30%)
#
# ====================================================================================================================================================
# GADGET: TransversalS
# ====================================================================================================================================================
# Code               | PyMatching | FusionBlos | BeliefMatc |   BPOSD    | Tesseract  | UnionFind  |    MLE     | Hypergraph | Hierarchic | SingleShot
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# XZZX_Surface_3     |   0.0040   |   0.0130   |   0.0080   |   0.0000   |   0.0000   |   0.0040   |   0.0000   |   0.0220   |    FAIL    |    FAIL
# LoopToricCode4D    | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# Hamming_CSS_15     |   0.0600   |   0.0300   |   0.0460   |   0.0170   |   0.0060   |   0.0600   |   0.0050   |   0.0820   |    FAIL    |    FAIL
# Code_832           | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# Colour488_[[9,1,3] |   0.0230   |   0.0280   |   0.0280   |   0.0120   |   0.0080   |   0.0230   |   0.0060   |   0.0230   |    FAIL    |    FAIL
# QuantumTanner_4    | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE
# BalancedProduct_5x | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE
# FourQubit422       |   0.0090   |   0.0070   |   0.0100   |   0.0100   |   0.0080   |   0.0090   |   0.0080   |   0.0090   |    FAIL    |    FAIL
# SteanCode713       |   0.0180   |   0.0240   |   0.0330   |   0.0060   |   0.0010   |   0.0180   |   0.0010   |   0.0340   |    FAIL    |    FAIL
# ShorCode91         |   0.0130   |   0.0240   |   0.0400   |   0.0310   |   0.0110   |   0.0130   |    SKIP    |   0.0290   |    FAIL    |    FAIL
# RotatedSurface_[[9 |   0.0070   |   0.0240   |   0.0060   |   0.0010   |   0.0010   |   0.0070   |   0.0030   |   0.0230   |    FAIL    |    FAIL
# RotatedSurface_[[2 | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# ToricCode_3x3      | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# ToricCode_5x5      |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# XZZX_Surface_5     |   0.0020   |   0.0370   |   0.0070   |   0.0000   |   0.0000   |   0.0020   |    SKIP    |   0.0460   |    FAIL    |    FAIL
# ToricCode4D_2      | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er
# ToricCode4D_3      | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er
# ToricCode3D_3x3x3  |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ToricCode3D_4x4x4  |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ToricCode3DFaces_3 |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# HyperbolicSurfaceC |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0000   |    FAIL    |    FAIL
# TwistedToric_[[32, | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# TwistedToric_4x4_[ | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# ProjectivePlaneSur |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0000   |    FAIL    |    FAIL
# TriangularColour_d |   0.0190   |   0.0180   |   0.0200   |   0.0080   |   0.0020   |   0.0190   |   0.0020   |   0.0310   |    FAIL    |    FAIL
# TriangularColour_d | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# HexagonalColour_d2 |   0.0000   |   0.0170   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0100   |    FAIL    |    FAIL
# HexagonalColour_d3 |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# TruncatedTrihexCol | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# ColorCode3D_d3     |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ColorCode3D_d5     |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ColorCode3DPrism_2 |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# TetrahedralColorCo |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# BallColorCode      |   0.0570   |   0.0680   |   0.0540   |   0.0130   |   0.0070   |   0.0570   |   0.0220   |   0.0960   |    FAIL    |    FAIL
# HyperbolicColorCod | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# GaugeColor_3       |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# Summary: 100/360 OK (28%)
#
# ====================================================================================================================================================
# GADGET: TransversalX
# ====================================================================================================================================================
# Code               | PyMatching | FusionBlos | BeliefMatc |   BPOSD    | Tesseract  | UnionFind  |    MLE     | Hypergraph | Hierarchic | SingleShot
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# XZZX_Surface_3     |   0.0010   |   0.0200   |   0.0100   |   0.0020   |   0.0010   |   0.0010   |    SKIP    |   0.0170   |    FAIL    |    FAIL
# LoopToricCode4D    |   0.0000   |   0.0520   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0000   |    FAIL    |    FAIL
# Hamming_CSS_15     |   0.0700   |   0.0280   |   0.0670   |   0.0100   |   0.0070   |   0.0700   |    SKIP    |   0.0910   |    FAIL    |    FAIL
# Code_832           | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# Colour488_[[9,1,3] |   0.0130   |   0.0440   |   0.0340   |   0.0190   |   0.0110   |   0.0130   |    SKIP    |   0.0130   |    FAIL    |    FAIL
# QuantumTanner_4    | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE
# BalancedProduct_5x | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE
# FourQubit422       |   0.0160   |   0.0130   |   0.0160   |   0.0160   |   0.0170   |   0.0160   |   0.0150   |   0.0170   |    FAIL    |    FAIL
# SteanCode713       |   0.0250   |   0.0190   |   0.0200   |   0.0060   |   0.0050   |   0.0250   |   0.0070   |   0.0240   |    FAIL    |    FAIL
# ShorCode91         |   0.0210   |   0.0470   |   0.0300   |   0.0360   |   0.0200   |   0.0210   |    SKIP    |   0.0340   |    FAIL    |    FAIL
# RotatedSurface_[[9 |   0.0010   |   0.0150   |   0.0110   |   0.0010   |   0.0010   |   0.0010   |    SKIP    |   0.0180   |    FAIL    |    FAIL
# RotatedSurface_[[2 |   0.0000   |   0.0350   |   0.0120   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0380   |    FAIL    |    FAIL
# ToricCode_3x3      |   0.0000   |   0.0260   |   0.0040   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0000   |    FAIL    |    FAIL
# ToricCode_5x5      |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# XZZX_Surface_5     |   0.0000   |   0.0300   |   0.0130   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0380   |    FAIL    |    FAIL
# ToricCode4D_2      | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# ToricCode4D_3      | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# ToricCode3D_3x3x3  |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ToricCode3D_4x4x4  |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ToricCode3DFaces_3 |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# HyperbolicSurfaceC |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0000   |    FAIL    |    FAIL
# TwistedToric_[[32, |   0.0000   |   0.1830   |   0.0450   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0000   |    FAIL    |    FAIL
# TwistedToric_4x4_[ |   0.0000   |   0.1670   |   0.0770   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0000   |    FAIL    |    FAIL
# ProjectivePlaneSur |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0000   |    FAIL    |    FAIL
# TriangularColour_d |   0.0150   |   0.0220   |   0.0140   |   0.0050   |   0.0020   |   0.0150   |   0.0020   |   0.0130   |    FAIL    |    FAIL
# TriangularColour_d | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# HexagonalColour_d2 |   0.0000   |   0.0400   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0090   |    FAIL    |    FAIL
# HexagonalColour_d3 |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# TruncatedTrihexCol |   0.0000   |   0.0240   |   0.0080   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0490   |    FAIL    |    FAIL
# ColorCode3D_d3     |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ColorCode3D_d5     |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ColorCode3DPrism_2 |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# TetrahedralColorCo |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# BallColorCode      |   0.0620   |   0.1060   |   0.0520   |   0.0130   |   0.0070   |   0.0620   |    SKIP    |   0.1080   |    FAIL    |    FAIL
# HyperbolicColorCod |   0.0000   |   0.0730   |   0.0500   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0000   |    FAIL    |    FAIL
# GaugeColor_3       |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# Summary: 144/360 OK (40%)
#
# ====================================================================================================================================================
# GADGET: TransversalY
# ====================================================================================================================================================
# Code               | PyMatching | FusionBlos | BeliefMatc |   BPOSD    | Tesseract  | UnionFind  |    MLE     | Hypergraph | Hierarchic | SingleShot
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# XZZX_Surface_3     |   0.0010   |   0.0220   |   0.0060   |   0.0030   |   0.0010   |   0.0010   |    SKIP    |   0.0200   |    FAIL    |    FAIL
# LoopToricCode4D    |   0.0000   |   0.0470   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0000   |    FAIL    |    FAIL
# Hamming_CSS_15     |   0.0430   |   0.0180   |   0.0520   |   0.0100   |   0.0080   |   0.0430   |    SKIP    |   0.0620   |    FAIL    |    FAIL
# Code_832           | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# Colour488_[[9,1,3] |   0.0040   |   0.0330   |   0.0270   |   0.0120   |   0.0060   |   0.0040   |    SKIP    |   0.0040   |    FAIL    |    FAIL
# QuantumTanner_4    | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE
# BalancedProduct_5x | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE
# FourQubit422       |   0.0110   |   0.0080   |   0.0070   |   0.0080   |   0.0070   |   0.0110   |   0.0100   |   0.0120   |    FAIL    |    FAIL
# SteanCode713       |   0.0100   |   0.0210   |   0.0130   |   0.0020   |   0.0000   |   0.0100   |   0.0000   |   0.0200   |    FAIL    |    FAIL
# ShorCode91         |   0.0240   |   0.0550   |   0.0320   |   0.0260   |   0.0110   |   0.0240   |    SKIP    |   0.0220   |    FAIL    |    FAIL
# RotatedSurface_[[9 |   0.0000   |   0.0220   |   0.0080   |   0.0010   |   0.0000   |   0.0000   |    SKIP    |   0.0240   |    FAIL    |    FAIL
# RotatedSurface_[[2 |   0.0000   |   0.0380   |   0.0080   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0390   |    FAIL    |    FAIL
# ToricCode_3x3      |   0.0010   |   0.0180   |   0.0080   |   0.0020   |   0.0020   |   0.0010   |    SKIP    |   0.0010   |    FAIL    |    FAIL
# ToricCode_5x5      |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# XZZX_Surface_5     |   0.0000   |   0.0280   |   0.0160   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0310   |    FAIL    |    FAIL
# ToricCode4D_2      | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# ToricCode4D_3      | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# ToricCode3D_3x3x3  |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ToricCode3D_4x4x4  |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ToricCode3DFaces_3 |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# HyperbolicSurfaceC |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0000   |    FAIL    |    FAIL
# TwistedToric_[[32, |   0.0000   |   0.1940   |   0.0720   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0000   |    FAIL    |    FAIL
# TwistedToric_4x4_[ |   0.0000   |   0.1760   |   0.0540   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0000   |    FAIL    |    FAIL
# ProjectivePlaneSur |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0000   |    FAIL    |    FAIL
# TriangularColour_d |   0.0190   |   0.0200   |   0.0210   |   0.0040   |   0.0050   |   0.0190   |   0.0040   |   0.0290   |    FAIL    |    FAIL
# TriangularColour_d | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# HexagonalColour_d2 |   0.0000   |   0.0490   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0090   |    FAIL    |    FAIL
# HexagonalColour_d3 |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# TruncatedTrihexCol |   0.0000   |   0.0320   |   0.0130   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0610   |    FAIL    |    FAIL
# ColorCode3D_d3     |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ColorCode3D_d5     |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ColorCode3DPrism_2 |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# TetrahedralColorCo |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# BallColorCode      |   0.0510   |   0.0980   |   0.0530   |   0.0190   |   0.0120   |   0.0510   |    SKIP    |   0.1040   |    FAIL    |    FAIL
# HyperbolicColorCod |   0.0000   |   0.0510   |   0.0450   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0000   |    FAIL    |    FAIL
# GaugeColor_3       |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# Summary: 144/360 OK (40%)
#
# ====================================================================================================================================================
# GADGET: TransversalZ
# ====================================================================================================================================================
# Code               | PyMatching | FusionBlos | BeliefMatc |   BPOSD    | Tesseract  | UnionFind  |    MLE     | Hypergraph | Hierarchic | SingleShot
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# XZZX_Surface_3     |   0.0000   |   0.0170   |   0.0070   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0180   |    FAIL    |    FAIL
# LoopToricCode4D    |   0.0000   |   0.0430   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0000   |    FAIL    |    FAIL
# Hamming_CSS_15     |   0.0540   |   0.0210   |   0.0550   |   0.0070   |   0.0070   |   0.0540   |    SKIP    |   0.0770   |    FAIL    |    FAIL
# Code_832           | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# Colour488_[[9,1,3] |   0.0090   |   0.0320   |   0.0220   |   0.0150   |   0.0050   |   0.0090   |    SKIP    |   0.0090   |    FAIL    |    FAIL
# QuantumTanner_4    | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE
# BalancedProduct_5x | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE
# FourQubit422       |   0.0130   |   0.0130   |   0.0240   |   0.0250   |   0.0160   |   0.0130   |   0.0110   |   0.0140   |    FAIL    |    FAIL
# SteanCode713       |   0.0250   |   0.0240   |   0.0260   |   0.0050   |   0.0040   |   0.0250   |   0.0060   |   0.0250   |    FAIL    |    FAIL
# ShorCode91         |   0.0210   |   0.0460   |   0.0310   |   0.0370   |   0.0170   |   0.0210   |    SKIP    |   0.0420   |    FAIL    |    FAIL
# RotatedSurface_[[9 |   0.0010   |   0.0190   |   0.0120   |   0.0030   |   0.0010   |   0.0010   |    SKIP    |   0.0250   |    FAIL    |    FAIL
# RotatedSurface_[[2 |   0.0000   |   0.0340   |   0.0110   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0360   |    FAIL    |    FAIL
# ToricCode_3x3      |   0.0000   |   0.0240   |   0.0040   |   0.0010   |   0.0000   |   0.0000   |    SKIP    |   0.0000   |    FAIL    |    FAIL
# ToricCode_5x5      |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# XZZX_Surface_5     |   0.0000   |   0.0370   |   0.0170   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0350   |    FAIL    |    FAIL
# ToricCode4D_2      | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# ToricCode4D_3      | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# ToricCode3D_3x3x3  |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ToricCode3D_4x4x4  |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ToricCode3DFaces_3 |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# HyperbolicSurfaceC |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0000   |    FAIL    |    FAIL
# TwistedToric_[[32, |   0.0000   |   0.1890   |   0.0740   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0000   |    FAIL    |    FAIL
# TwistedToric_4x4_[ |   0.0000   |   0.1890   |   0.0560   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0000   |    FAIL    |    FAIL
# ProjectivePlaneSur |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0000   |    FAIL    |    FAIL
# TriangularColour_d |   0.0170   |   0.0210   |   0.0210   |   0.0090   |   0.0060   |   0.0170   |   0.0030   |   0.0190   |    FAIL    |    FAIL
# TriangularColour_d | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# HexagonalColour_d2 |   0.0000   |   0.0440   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0100   |    FAIL    |    FAIL
# HexagonalColour_d3 |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# TruncatedTrihexCol |   0.0000   |   0.0370   |   0.0070   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0690   |    FAIL    |    FAIL
# ColorCode3D_d3     |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ColorCode3D_d5     |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ColorCode3DPrism_2 |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# TetrahedralColorCo |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# BallColorCode      |   0.0520   |   0.1010   |   0.0670   |   0.0180   |   0.0070   |   0.0520   |    SKIP    |   0.1000   |    FAIL    |    FAIL
# HyperbolicColorCod |   0.0000   |   0.0790   |   0.0620   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0000   |    FAIL    |    FAIL
# GaugeColor_3       |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# Summary: 144/360 OK (40%)
#
# ====================================================================================================================================================
# GADGET: TransversalCNOT
# ====================================================================================================================================================
# Code               | PyMatching | FusionBlos | BeliefMatc |   BPOSD    | Tesseract  | UnionFind  |    MLE     | Hypergraph | Hierarchic | SingleShot
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# XZZX_Surface_3     |   0.0130   |   0.0150   |   0.0140   |   0.0020   |   0.0010   |   0.0130   |    SKIP    |   0.0250   |    FAIL    |    FAIL
# LoopToricCode4D    | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# Hamming_CSS_15     | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er
# Code_832           | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# Colour488_[[9,1,3] |   0.0310   |   0.0620   |   0.0700   |   0.0400   |   0.0130   |   0.0310   |    SKIP    |   0.0310   |    FAIL    |    FAIL
# QuantumTanner_4    | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE
# BalancedProduct_5x | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE
# FourQubit422       |   0.0180   |   0.0290   |   0.0360   |   0.0350   |   0.0170   |   0.0180   |   0.0190   |   0.0220   |    FAIL    |    FAIL
# SteanCode713       | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# ShorCode91         |   0.0270   |   0.0510   |   0.0530   |   0.0440   |   0.0230   |   0.0270   |    SKIP    |   0.0550   |    FAIL    |    FAIL
# RotatedSurface_[[9 |   0.0110   |   0.0220   |   0.0110   |   0.0000   |   0.0000   |   0.0110   |    SKIP    |   0.0430   |    FAIL    |    FAIL
# RotatedSurface_[[2 | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# ToricCode_3x3      | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# ToricCode_5x5      |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# XZZX_Surface_5     |   0.0020   |   0.0350   |   0.0110   |   0.0000   |   0.0000   |   0.0020   |    SKIP    |   0.0720   |    FAIL    |    FAIL
# ToricCode4D_2      | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er
# ToricCode4D_3      | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er
# ToricCode3D_3x3x3  |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ToricCode3D_4x4x4  |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ToricCode3DFaces_3 |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# HyperbolicSurfaceC | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# TwistedToric_[[32, | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# TwistedToric_4x4_[ | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# ProjectivePlaneSur | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er
# TriangularColour_d | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# TriangularColour_d | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# HexagonalColour_d2 |   0.0000   |   0.0160   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0280   |    FAIL    |    FAIL
# HexagonalColour_d3 |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# TruncatedTrihexCol | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# ColorCode3D_d3     |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ColorCode3D_d5     |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ColorCode3DPrism_2 |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# TetrahedralColorCo |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# BallColorCode      | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er
# HyperbolicColorCod | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# GaugeColor_3       |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# Summary: 50/360 OK (14%)
#
# ====================================================================================================================================================
# GADGET: TransversalCZ
# ====================================================================================================================================================
# Code               | PyMatching | FusionBlos | BeliefMatc |   BPOSD    | Tesseract  | UnionFind  |    MLE     | Hypergraph | Hierarchic | SingleShot
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# XZZX_Surface_3     |   0.0120   |   0.0140   |   0.0130   |   0.0000   |   0.0000   |   0.0120   |    SKIP    |   0.0230   |    FAIL    |    FAIL
# LoopToricCode4D    | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# Hamming_CSS_15     |   0.0650   |   0.0340   |   0.0580   |   0.0100   |   0.0110   |   0.0650   |    SKIP    |   0.0640   |    FAIL    |    FAIL
# Code_832           | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# Colour488_[[9,1,3] |   0.0250   |   0.0330   |   0.0430   |   0.0170   |   0.0070   |   0.0250   |    SKIP    |   0.0250   |    FAIL    |    FAIL
# QuantumTanner_4    | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE
# BalancedProduct_5x | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE
# FourQubit422       |   0.0130   |   0.0130   |   0.0130   |   0.0130   |   0.0090   |   0.0130   |   0.0110   |   0.0110   |    FAIL    |    FAIL
# SteanCode713       |   0.0130   |   0.0260   |   0.0180   |   0.0080   |   0.0030   |   0.0130   |    SKIP    |   0.0300   |    FAIL    |    FAIL
# ShorCode91         |   0.0150   |   0.0300   |   0.0340   |   0.0360   |   0.0130   |   0.0150   |    SKIP    |   0.0170   |    FAIL    |    FAIL
# RotatedSurface_[[9 |   0.0130   |   0.0120   |   0.0100   |   0.0030   |   0.0000   |   0.0130   |    SKIP    |   0.0240   |    FAIL    |    FAIL
# RotatedSurface_[[2 | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# ToricCode_3x3      | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# ToricCode_5x5      |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# XZZX_Surface_5     |   0.0010   |   0.0210   |   0.0030   |   0.0000   |   0.0000   |   0.0010   |    SKIP    |   0.0360   |    FAIL    |    FAIL
# ToricCode4D_2      | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er
# ToricCode4D_3      | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er
# ToricCode3D_3x3x3  |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ToricCode3D_4x4x4  |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ToricCode3DFaces_3 |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# HyperbolicSurfaceC |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0000   |    FAIL    |    FAIL
# TwistedToric_[[32, | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# TwistedToric_4x4_[ | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# ProjectivePlaneSur |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0000   |    FAIL    |    FAIL
# TriangularColour_d |   0.0170   |   0.0170   |   0.0130   |   0.0080   |   0.0040   |   0.0170   |    SKIP    |   0.0270   |    FAIL    |    FAIL
# TriangularColour_d | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# HexagonalColour_d2 |   0.0000   |   0.0060   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0090   |    FAIL    |    FAIL
# HexagonalColour_d3 |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# TruncatedTrihexCol | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# ColorCode3D_d3     |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ColorCode3D_d5     |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ColorCode3DPrism_2 |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# TetrahedralColorCo |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# BallColorCode      |   0.0520   |   0.0600   |   0.0530   |   0.0130   |   0.0070   |   0.0520   |    SKIP    |   0.0660   |    FAIL    |    FAIL
# HyperbolicColorCod | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# GaugeColor_3       |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# Summary: 92/360 OK (26%)
#
# ====================================================================================================================================================
# GADGET: TransversalSWAP
# ====================================================================================================================================================
# Code               | PyMatching | FusionBlos | BeliefMatc |   BPOSD    | Tesseract  | UnionFind  |    MLE     | Hypergraph | Hierarchic | SingleShot
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# XZZX_Surface_3     |   0.0120   |   0.0180   |   0.0140   |   0.0030   |   0.0010   |   0.0120   |    SKIP    |   0.0250   |    FAIL    |    FAIL
# LoopToricCode4D    | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# Hamming_CSS_15     |   0.0710   |   0.0400   |   0.0600   |   0.0110   |   0.0050   |   0.0710   |    SKIP    |   0.0550   |    FAIL    |    FAIL
# Code_832           | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# Colour488_[[9,1,3] |   0.0190   |   0.0270   |   0.0520   |   0.0250   |   0.0020   |   0.0190   |    SKIP    |   0.0190   |    FAIL    |    FAIL
# QuantumTanner_4    | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE
# BalancedProduct_5x | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE
# FourQubit422       |   0.0090   |   0.0120   |   0.0200   |   0.0190   |   0.0070   |   0.0090   |   0.0080   |   0.0090   |    FAIL    |    FAIL
# SteanCode713       |   0.0230   |   0.0170   |   0.0180   |   0.0090   |   0.0040   |   0.0230   |    SKIP    |   0.0210   |    FAIL    |    FAIL
# ShorCode91         |   0.0170   |   0.0300   |   0.0330   |   0.0320   |   0.0110   |   0.0170   |    SKIP    |   0.0280   |    FAIL    |    FAIL
# RotatedSurface_[[9 |   0.0110   |   0.0150   |   0.0130   |   0.0010   |   0.0000   |   0.0110   |    SKIP    |   0.0230   |    FAIL    |    FAIL
# RotatedSurface_[[2 | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# ToricCode_3x3      | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# ToricCode_5x5      |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# XZZX_Surface_5     |   0.0030   |   0.0220   |   0.0040   |   0.0000   |   0.0000   |   0.0030   |    SKIP    |   0.0290   |    FAIL    |    FAIL
# ToricCode4D_2      | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er
# ToricCode4D_3      | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er
# ToricCode3D_3x3x3  |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ToricCode3D_4x4x4  |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ToricCode3DFaces_3 |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# HyperbolicSurfaceC |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0000   |    FAIL    |    FAIL
# TwistedToric_[[32, | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# TwistedToric_4x4_[ | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# ProjectivePlaneSur |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0000   |    FAIL    |    FAIL
# TriangularColour_d |   0.0200   |   0.0190   |   0.0200   |   0.0080   |   0.0060   |   0.0200   |    SKIP    |   0.0240   |    FAIL    |    FAIL
# TriangularColour_d | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# HexagonalColour_d2 |   0.0000   |   0.0070   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0110   |    FAIL    |    FAIL
# HexagonalColour_d3 |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ...
# ToricCode_3x3      |   0.0160   |   0.0180   |   0.0660   |   0.0470   |   0.0120   |   0.0160   |    SKIP    |   0.0160   |    FAIL    |    FAIL
# ToricCode_5x5      |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# XZZX_Surface_5     |   0.0100   |   0.0190   |   0.0360   |   0.0210   |   0.0140   |   0.0100   |    SKIP    |   0.0250   |    FAIL    |    FAIL
# ToricCode4D_2      | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# ToricCode4D_3      | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# ToricCode3D_3x3x3  |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ToricCode3D_4x4x4  |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ToricCode3DFaces_3 |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# HyperbolicSurfaceC |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0000   |    FAIL    |    FAIL
# TwistedToric_[[32, |   0.0900   |   0.1390   |   0.1550   |   0.1150   |   0.0830   |   0.0900   |    SKIP    |   0.0900   |    FAIL    |    FAIL
# TwistedToric_4x4_[ |   0.0770   |   0.1300   |   0.1530   |   0.1160   |   0.0660   |   0.0770   |    SKIP    |   0.0770   |    FAIL    |    FAIL
# ProjectivePlaneSur |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0000   |    FAIL    |    FAIL
# TriangularColour_d |   0.0230   |   0.0180   |   0.0340   |   0.0300   |   0.0090   |   0.0230   |    SKIP    |   0.0200   |    FAIL    |    FAIL
# TriangularColour_d | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# HexagonalColour_d2 |   0.0220   |   0.0310   |   0.0280   |   0.0260   |   0.0210   |   0.0220   |    SKIP    |   0.0220   |    FAIL    |    FAIL
# HexagonalColour_d3 |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# TruncatedTrihexCol |   0.0290   |   0.0360   |   0.0760   |   0.0430   |   0.0190   |   0.0290   |    SKIP    |   0.0670   |    FAIL    |    FAIL
# ColorCode3D_d3     |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ColorCode3D_d5     |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ColorCode3DPrism_2 |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# TetrahedralColorCo |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# BallColorCode      |   0.0700   |   0.0920   |   0.0850   |   0.0690   |   0.0550   |   0.0700   |    SKIP    |   0.1050   |    FAIL    |    FAIL
# HyperbolicColorCod |   0.0280   |   0.0500   |   0.0950   |   0.0690   |   0.0210   |   0.0280   |    SKIP    |   0.0280   |    FAIL    |    FAIL
# GaugeColor_3       |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# Summary: 141/360 OK (39%)
#
# ====================================================================================================================================================
# GADGET: SurgeryCNOT
# ====================================================================================================================================================
# Code               | PyMatching | FusionBlos | BeliefMatc |   BPOSD    | Tesseract  | UnionFind  |    MLE     | Hypergraph | Hierarchic | SingleShot
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# XZZX_Surface_3     |   0.0240   |   0.0230   |   0.0320   |   0.0220   |   0.0160   |   0.0240   |    SKIP    |   0.0320   |    FAIL    |    FAIL
# LoopToricCode4D    | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# Hamming_CSS_15     |   0.0670   |   0.0640   |   0.0710   |   0.0440   |   0.0220   |   0.0670   |    SKIP    |   0.0810   |    FAIL    |    FAIL
# Code_832           | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# Colour488_[[9,1,3] |   0.0400   |   0.0470   |   0.0530   |   0.0460   |   0.0280   |   0.0400   |    SKIP    |   0.0400   |    FAIL    |    FAIL
# QuantumTanner_4    | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE
# BalancedProduct_5x | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE | UNSUPPORTE
# FourQubit422       |   0.0180   |   0.0180   |   0.0210   |   0.0210   |   0.0120   |   0.0180   |   0.0150   |   0.0180   |    FAIL    |    FAIL
# SteanCode713       |   0.0200   |   0.0250   |   0.0340   |   0.0200   |   0.0100   |   0.0200   |    SKIP    |   0.0200   |    FAIL    |    FAIL
# ShorCode91         |   0.0430   |   0.0400   |   0.0540   |   0.0420   |   0.0350   |   0.0430   |    SKIP    |   0.0520   |    FAIL    |    FAIL
# RotatedSurface_[[9 |   0.0180   |   0.0250   |   0.0170   |   0.0100   |   0.0100   |   0.0180   |    SKIP    |   0.0200   |    FAIL    |    FAIL
# RotatedSurface_[[2 |   0.0420   |   0.0450   |   0.0470   |   0.0400   |   0.0300   |   0.0420   |    SKIP    |   0.0510   |    FAIL    |    FAIL
# ToricCode_3x3      | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# ToricCode_5x5      |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# XZZX_Surface_5     |   0.0270   |   0.0310   |   0.0380   |   0.0260   |   0.0150   |   0.0270   |    SKIP    |   0.0400   |    FAIL    |    FAIL
# ToricCode4D_2      | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er
# ToricCode4D_3      | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er | DEM: An er
# ToricCode3D_3x3x3  |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ToricCode3D_4x4x4  |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ToricCode3DFaces_3 |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# HyperbolicSurfaceC |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0000   |    FAIL    |    FAIL
# TwistedToric_[[32, | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# TwistedToric_4x4_[ | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# ProjectivePlaneSur |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |   0.0000   |    SKIP    |   0.0000   |    FAIL    |    FAIL
# TriangularColour_d |   0.0270   |   0.0240   |   0.0240   |   0.0220   |   0.0140   |   0.0270   |    SKIP    |   0.0260   |    FAIL    |    FAIL
# TriangularColour_d | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# HexagonalColour_d2 |   0.0240   |   0.0320   |   0.0280   |   0.0260   |   0.0200   |   0.0240   |    SKIP    |   0.0300   |    FAIL    |    FAIL
# HexagonalColour_d3 |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# TruncatedTrihexCol | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# ColorCode3D_d3     |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ColorCode3D_d5     |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ColorCode3DPrism_2 |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# TetrahedralColorCo |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# BallColorCode      |   0.0890   |   0.0990   |   0.0850   |   0.0490   |   0.0390   |   0.0890   |    SKIP    |   0.1320   |    FAIL    |    FAIL
# HyperbolicColorCod | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile | DEM: Faile
# GaugeColor_3       |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR   |  DET_ERR
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# Summary: 99/360 OK (28%)
#
# ============================================================
# SKIPPED GADGETS
# ============================================================
#   TransversalT             : Non-Clifford (Stim cannot simulate)
#
# ====================================================================================================
# OVERALL SUMMARY: All Gadgets × All Codes × All Decoders
# ====================================================================================================
#
# Total test combinations: 5400
#   ✓ OK:          1834 (34.0%)
#   ⚠ DET_ERR:     1500 (27.8%) - Non-deterministic detectors
#   ⊘ UNSUPPORTED:  300 (5.6%) - Code not supported
#   ~ SKIP:         206 (3.8%) - Decoder incompatible
#   ✗ FAIL:        1560 (28.9%) - Decoder error
#
# --------------------------------------------------------------------------------
# Per-Gadget Summary:
# --------------------------------------------------------------------------------
# Gadget                    |     OK | DET_ERR |   FAIL |   SKIP |   Rate
# --------------------------------------------------------------------------------
# TransversalH              |    108 |     100 |     28 |      4 |    30%
# TransversalS              |    100 |     100 |     26 |      4 |    28%
# TransversalX              |    144 |     100 |     40 |     16 |    40%
# TransversalY              |    144 |     100 |     40 |     16 |    40%
# TransversalZ              |    144 |     100 |     40 |     16 |    40%
# TransversalCNOT           |     50 |     100 |     14 |      6 |    14%
# TransversalCZ             |     92 |     100 |     26 |     12 |    26%
# TransversalSWAP           |     92 |     100 |     26 |     12 |    26%
# TeleportedH               |    159 |     100 |     44 |     17 |    44%
# TeleportedIdentity        |    159 |     100 |     44 |     17 |    44%
# BellTeleportedS           |    155 |     100 |     44 |     21 |    43%
# BellTeleportedSDag        |    155 |     100 |     44 |     21 |    43%
# LatticeZZMerge            |     92 |     100 |     26 |     12 |    26%
# LatticeXXMerge            |    141 |     100 |     40 |     19 |    39%
# SurgeryCNOT               |     99 |     100 |     28 |     13 |    28%
#
# --------------------------------------------------------------------------------
# Per-Code Summary:
# --------------------------------------------------------------------------------
# Code                      |     OK | DET_ERR |   FAIL |   SKIP |   Rate
# --------------------------------------------------------------------------------
# XZZX_Surface_3            |    107 |       0 |     30 |     13 |    71%
# LoopToricCode4D           |     56 |       0 |     86 |      8 |    37%
# Hamming_CSS_15            |    100 |       0 |     38 |     12 |    67%
# Code_832                  |     38 |       0 |    110 |      2 |    25%
# Colour488_[[9,1,3]]       |    107 |       0 |     30 |     13 |    71%
# QuantumTanner_4           |      0 |       0 |    150 |      0 |     0%
# BalancedProduct_5x5_G1    |      0 |       0 |    150 |      0 |     0%
# FourQubit422              |    120 |       0 |     30 |      0 |    80%
# SteanCode713              |    105 |       0 |     38 |      7 |    70%
# ShorCode91                |    105 |       0 |     30 |     15 |    70%
# RotatedSurface_[[9,1,3]]  |    107 |       0 |     30 |     13 |    71%
# RotatedSurface_[[25,1,5]] |     63 |       0 |     78 |      9 |    42%
# ToricCode_3x3             |     56 |       0 |     86 |      8 |    37%
# ToricCode_5x5             |      0 |     150 |      0 |      0 |     0%
# XZZX_Surface_5            |    105 |       0 |     30 |     15 |    70%
# ToricCode4D_2             |      0 |       0 |    150 |      0 |     0%
# ToricCode4D_3             |      0 |       0 |    150 |      0 |     0%
# ToricCode3D_3x3x3         |      0 |     150 |      0 |      0 |     0%
# ToricCode3D_4x4x4         |      0 |     150 |      0 |      0 |     0%
# ToricCode3DFaces_3x3x3    |      0 |     150 |      0 |      0 |     0%
# HyperbolicSurfaceCode     |     98 |       0 |     38 |     14 |    65%
# TwistedToric_[[32,2,None] |     56 |       0 |     86 |      8 |    37%
# TwistedToric_4x4_[[32,2,N |     56 |       0 |     86 |      8 |    37%
# ProjectivePlaneSurface_[[ |     98 |       0 |     38 |     14 |    65%
# TriangularColour_d3       |    105 |       0 |     38 |      7 |    70%
# TriangularColour_d5       |     28 |       0 |    118 |      4 |    19%
# HexagonalColour_d2        |    112 |       0 |     30 |      8 |    75%
# HexagonalColour_d3        |      0 |     150 |      0 |      0 |     0%
# TruncatedTrihexColorCode  |     56 |       0 |     86 |      8 |    37%
# ColorCode3D_d3            |      0 |     150 |      0 |      0 |     0%
# ColorCode3D_d5            |      0 |     150 |      0 |      0 |     0%
# ColorCode3DPrism_2x3      |      0 |     150 |      0 |      0 |     0%
# TetrahedralColorCode      |      0 |     150 |      0 |      0 |     0%
# BallColorCode             |    100 |       0 |     38 |     12 |    67%
# HyperbolicColorCode       |     56 |       0 |     86 |      8 |    37%
# GaugeColor_3              |      0 |     150 |      0 |      0 |     0%
#
# --------------------------------------------------------------------------------
# Per-Decoder Summary:
# --------------------------------------------------------------------------------
# Decoder         |     OK | DET_ERR |   FAIL |   SKIP |   Rate
# --------------------------------------------------------------------------------
# PyMatching      |    255 |     150 |    135 |      0 |    47%
# FusionBlossom   |    255 |     150 |    135 |      0 |    47%
# BeliefMatching  |    255 |     150 |    135 |      0 |    47%
# BPOSD           |    255 |     150 |    135 |      0 |    47%
# Tesseract       |    255 |     150 |    135 |      0 |    47%
# UnionFind       |    255 |     150 |    135 |      0 |    47%
# MLE             |     49 |     150 |    135 |    206 |     9%
# Hypergraph      |    255 |     150 |    135 |      0 |    47%
# Hierarchical    |      0 |     150 |    390 |      0 |     0%
# SingleShot      |      0 |     150 |    390 |      0 |     0%
